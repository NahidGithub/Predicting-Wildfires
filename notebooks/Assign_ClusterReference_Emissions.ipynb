# %% [markdown]
# # Assign Cluster Reference label from DBScan to Emissions and NASA M6 records.
# Includes a review and removal of duplicate records.

# %%
import pandas as pd
import numpy as np
import math
import datetime

from sqlalchemy import create_engine
import config
import config1

# %%
# Expanding number of columns:
pd.set_option('display.max_columns', 40)

# %% [markdown]
# ### One-Time - Combining Cluster Point CSVs into single dataset of underlying emissions records with cluster references:

# %% [raw]
# #Combine all csv's saved in a singlel directory, into a new CSV file.
# import os
# import glob
# import pandas as pd
#
# os.chdir('../data/Emissions Cluster Data/EmissionClusterPoints')
#
# extension = 'csv'
# all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
#
# #combine all files in the list
# clusterpoints_03_15_v2 = pd.concat([pd.read_csv(f) for f in all_filenames ])
#
# ###export to csv
# clusterpoints_03_15_v2.to_csv( "clusterpoints_03_15_v2.csv", index=False, encoding='utf-8-sig')

# %% [markdown]
# ### Load related DataFrames: Fire Center Points from Emissions, Cluster Points, Emissions from DB.

# %%
config.db_name  # Checking name of DB.
# Out:
# 'db27bvsdruzh45'

# %%
# Create sqlalchemy engine to access database:
engine = create_engine("mysql+mysqlconnector://{user}:{password}@{host}/{dbname}"
                       .format(user=config.db_user,
                               password=config.db_pass,
                               dbname=config.db_main,
                               host=config.db_host))

# %%
### Skip this block if reading from local disk:

#Create Query Statments
queryWeather = """
SELECT *
FROM Weather;
"""
queryEmissions = """
SELECT *
FROM Emissions_Data;
"""
queryNASA = """
SELECT *
FROM NASA;
"""

# %%
emdata_0315 = pd.read_sql(queryEmissions, engine)  # Bring in Emissions records (w/o Null Values) from database.

# %%
fire_centerpoints = pd.read_csv('../data/centerpoints_03_15_v2.csv')

# %%
ClusterPoints = pd.read_csv('../data/clusterpoints_03_15_v2.csv', encoding='utf-8')

# %% [raw]
# emdata_0315 = pd.read_csv('../data/emissions_2003to2015_cleanv1.csv')  # If pull from disk is needed.

# %% [markdown]
# ### Emissions Data

# %%
print(emdata_0315.shape)
emdata_0315.head(2)
# Out:
# (5960572, 20)
#    index  Unnamed: 0  year  doy  longitude  latitude  covertype  fuelcode  \
# 0      0           0  2008  359   -81.0384   25.1958          3      1600
# 1      1           1  2008  359   -81.0404   25.1984          3      1600
#
#    area_burned  prefire_fuel  consumed_fuel         ECO2         ECO  \
# 0          0.0   6220.097576     1999.75772  3347.594423  153.981344
# 1      62500.0   6220.097576     2041.37434  3417.260644  157.185824
#
#        ECH4     EPM2.5  cwd_frac  duff_frac  fuel_moisture_class  \
# 0  4.499455  23.797117  0.023231   0.082115                    3
# 1  4.593092  24.292355  0.022757   0.080441                    3
#
#    burnday_source  BSEV
# 0              81     1
# 1              81     2

# %%
emdata_20xx = emdata_0315[emdata_0315.year == 2004]
emdata_20xx.head(2)

# %% [markdown]
# ### Fire Cluster Points data from DBScan.
# Detailed records of all underlying emissions records for each created cluster reference from DBScan.

# %%
print(ClusterPoints.shape)
ClusterPoints[200000:200005]
# Out:
# (5960572, 5)
#         Unnamed: 0        0         1  ClusterNum  Year
# 200000      200000  31.7406 -109.2987         361  2011
# 200001      200001  31.7409 -109.2961         361  2011
# 200002      200002  31.7412 -109.2935         361  2011
# 200003      200003  31.7415 -109.2909         361  2011
# 200004      200004  31.7418 -109.2882         361  2011

# %% [markdown]
# ### Creating New Fire Cluster Point Dataframe:
# 1. Dropping unused columns
# 2. Renaming column headers
# 3. Assigning new Cluster Reference to cluster points

# %%
ClusterPoints = ClusterPoints.drop(columns=['Unnamed: 0'])  # Dropping column. 
ClusterPoints[0:1]
# Out:
#          0        1  ClusterNum  Year
# 0  25.1903 -81.0394           0  2011

# %%
ClusterPoints = ClusterPoints.rename(columns={'0': 'latitude', '1': 'longitude', 'Year': 'year'})  # Rename 0,1 to Lat/Long. 
ClusterPoints[0:5]
# Out:
#    latitude  longitude  ClusterNum  year
# 0   25.1903   -81.0394           0  2011
# 1   25.1900   -81.0370           0  2011
# 2   25.1896   -81.0346           0  2011
# 3   25.1926   -81.0390           0  2011
# 4   25.1922   -81.0366           0  2011

# %%
### Create new Cluster Reference label from original cluster number from DBscan and Year. 
ClusterPoints['cluster_reference'] = ClusterPoints['year'].astype(str) + "_" + ClusterPoints['ClusterNum'].astype(str)
ClusterPoints[0:10]
# Out:
#    latitude  longitude  ClusterNum  year cluster_reference
# 0   25.1903   -81.0394           0  2011            2011_0
# 1   25.1900   -81.0370           0  2011            2011_0
# 2   25.1896   -81.0346           0  2011            2011_0
# 3   25.1926   -81.0390           0  2011            2011_0
# 4   25.1922   -81.0366           0  2011            2011_0
# 5   25.1918   -81.0342           0  2011            2011_0
# 6   25.1995   -81.0701           0  2011            2011_0
# 7   25.1991   -81.0677           0  2011            2011_0
# 8   25.1952   -81.0411           0  2011            2011_0
# 9   25.1948   -81.0386           0  2011            2011_0

# %%
# Checking shape. 
print(ClusterPoints.shape)
# Out:
# (5960572, 5)

# %%
# Determining unique cluster reference points.  Using .Unique() will include blanks. 
f = len(ClusterPoints['cluster_reference'].unique())
print(f)
# Out:
# 109321

# %%
# Writing new dataset of emissions cluster points with cluster reference ID to CSV:
ClusterPoints.to_csv('../data/Emissions Cluster Data/clusterpoints_03_15_ref1.csv', encoding='utf-8')

# %% [markdown]
# ## Fire Centerpoints from DBScan:
# 1. Renaming columns,
# 2. Adding cluster_reference id,
# 3. Moving column.

# %%
print(fire_centerpoints.shape) # Checking shape, and rows match to the detailed cluster points dataframe. 
fire_centerpoints[0:2]
# Out:
# (109321, 23)
#    Unnamed: 0    id    year    doy  longitude  latitude  grid10k  covertype  \
# 0           0  22.0  2006.0  208.0   -80.6759   25.4076   5461.0        1.0
# 1           1  96.0  2006.0  157.0   -80.5824   25.6130   6845.0        1.0
#
#    fuelcode  area_burned  prefire_fuel  consumed_fuel        ECO2        ECO  \
# 0       1.0      62500.0    394.430634     366.820490  615.157961  25.677434
# 1       1.0      62500.0    299.942136     278.946186  467.792755  19.526233
#
#        ECH4    EPM2.5  cwd_frac  duff_frac  fuel_moisture_class  burn_source  \
# 0  0.983079  3.741569       0.0        0.0                  2.0          1.0
# 1  0.747576  2.845251       0.0        0.0                  2.0          1.0
#
#    burnday_source  BSEV  BSEV_flag
# 0            15.0   2.0        0.0
# 1            81.0   2.0        0.0

# %%
fire_centerpoints = fire_centerpoints.rename(columns={'Unnamed: 0': 'cluster_ref'})

# %%
fire_centerpoints = fire_centerpoints.astype({"year": int})

# %%
fire_centerpoints.head(1)
# Out:
#    cluster_ref    id  year    doy  longitude  latitude  grid10k  covertype  \
# 0            0  22.0  2006  208.0   -80.6759   25.4076   5461.0        1.0
#
#    fuelcode  area_burned  prefire_fuel  consumed_fuel        ECO2        ECO  \
# 0       1.0      62500.0    394.430634      366.82049  615.157961  25.677434
#
#        ECH4    EPM2.5  cwd_frac  duff_frac  fuel_moisture_class  burn_source  \
# 0  0.983079  3.741569       0.0        0.0                  2.0          1.0
#
#    burnday_source  BSEV  BSEV_flag
# 0            15.0   2.0        0.0

# %%
### Create new Cluster Reference label from original cluster number from DBscan and Year. 
fire_centerpoints['cluster_reference'] = fire_centerpoints['year'].astype(str) + "_" + fire_centerpoints['cluster_ref'].astype(str)

# %%
fire_centerpoints[0:5]
# Out:
#    cluster_ref     id  year    doy  longitude  latitude  grid10k  covertype  \
# 0            0   22.0  2006  208.0   -80.6759   25.4076   5461.0        1.0
# 1            1   96.0  2006  157.0   -80.5824   25.6130   6845.0        1.0
# 2            2  164.0  2006  157.0   -80.5513   25.6198   6845.0        1.0
# 3            3  718.0  2006   49.0   -81.1249   26.0165   8222.0        3.0
# 4            4  444.0  2006  155.0   -81.6018   26.0708   8217.0        3.0
#
#    fuelcode  area_burned  prefire_fuel  consumed_fuel         ECO2  \
# 0       1.0      62500.0    394.430634     366.820490   615.157961
# 1       1.0      62500.0    299.942136     278.946186   467.792755
# 2       1.0      62500.0    226.077462     210.252040   352.592671
# 3    1600.0      62500.0   6220.097576    2017.491592  3377.280924
# 4    1140.0      62500.0   7646.952224    3842.452183  6432.264954
#
#           ECO      ECH4     EPM2.5  cwd_frac  duff_frac  fuel_moisture_class  \
# 0   25.677434  0.983079   3.741569  0.000000   0.000000                  2.0
# 1   19.526233  0.747576   2.845251  0.000000   0.000000                  2.0
# 2   14.717643  0.563475   2.144571  0.000000   0.000000                  2.0
# 3  155.346853  4.539356  24.008150  0.011189   0.081394                  4.0
# 4  295.868818  8.645517  45.725181  0.008857   0.084716                  2.0
#
#    burn_source  burnday_source  BSEV  BSEV_flag cluster_reference
# 0          1.0            15.0   2.0        0.0            2006_0
# 1          1.0            81.0   2.0        0.0            2006_1
# 2          1.0            15.0   2.0        0.0            2006_2
# 3          1.0            15.0   2.0        0.0            2006_3
# 4          1.0            15.0   2.0        1.0            2006_4

# %%
# Move cluster reference label to front of columns. 
first_col = fire_centerpoints.pop('cluster_reference')
fire_centerpoints.insert(1, 'cluster_reference', first_col)
fire_centerpoints[0:2]
# Out:
#    cluster_ref cluster_reference    id  year    doy  longitude  latitude  \
# 0            0            2006_0  22.0  2006  208.0   -80.6759   25.4076
# 1            1            2006_1  96.0  2006  157.0   -80.5824   25.6130
#
#    grid10k  covertype  fuelcode  area_burned  prefire_fuel  consumed_fuel  \
# 0   5461.0        1.0       1.0      62500.0    394.430634     366.820490
# 1   6845.0        1.0       1.0      62500.0    299.942136     278.946186
#
#          ECO2        ECO      ECH4    EPM2.5  cwd_frac  duff_frac  \
# 0  615.157961  25.677434  0.983079  3.741569       0.0        0.0
# 1  467.792755  19.526233  0.747576  2.845251       0.0        0.0
#
#    fuel_moisture_class  burn_source  burnday_source  BSEV  BSEV_flag
# 0                  2.0          1.0            15.0   2.0        0.0
# 1                  2.0          1.0            81.0   2.0        0.0

# %% [markdown]
# -----
# ---

# %% [markdown]
# # Manual Review of Centerpoint data for clusters that appear to be duplicates and can be merged.
# 1. Center Points: identify duplicates in Centerpoint data using DOY, Year, and alternating Lat and Long to then merge cluster coordinates into a single cluster based on distance on the same day of review.
# 2. Based on the manual review, create short list of cluster references to merge.

# %%
centerpoint_dupes = fire_centerpoints[fire_centerpoints.duplicated(['doy', 'year', 'longitude'],keep=False)]
centerpoint_dupes_lat = fire_centerpoints[fire_centerpoints.duplicated(['doy', 'year', 'latitude'],keep=False)]

# %%
print(centerpoint_dupes_lat.shape)
centerpoint_dupes_lat[50:59]

# %%
### Research into single duplicate in the Fire CenterPoint Data:
day = 75
lg = -82.9603

fire_centerpoints.loc[(FireCenterPoints['year'] == 2013) & (FireCenterPoints['doy'] == day) &(FireCenterPoints['longitude'] == lg),['cluster_reference', 'year', 'doy', 'longitude', 'latitude']]

# %%
# Seeing how many cluster points are related to the cluster reference, in determining which to merge. 
c1 = '2010_7596'
c2 = '2010_7597'

a = ClusterPoints.loc[(ClusterPoints['cluster_reference'] == c1)]
b = ClusterPoints.loc[(ClusterPoints['cluster_reference'] == c2)]
print(len(a), len(b))
print(b[0:10])
print(a[0:10])

# %% [markdown]
# ## Duplicate Centerpoints / Merging list based on manual review:
# - 2006_1874 same as 2006_1880 = merged 2006_1874 into 2006_1880.
#          2006_3171 lat is off by 2 from 2006_3568
#          2006_5430 not equal to '2006_10010'
# - 2006_11021 merged into 2006_11012
# - 2004_5765 merged into 2004_5772
# - 2005_7122 merged into 2005_228
# - 2003_3553 mergred into 2003_3572
# - 2003_5931 merged into 2003_722
# - 2008_2209 merged into 2008_2201
#         '2008_4900' not eq to '2008_6046'
# - 2008_7540 merged into 2008_7603
# - 2009_1551 merged into 2009_1554
# - 2009_1952 merged into 2009_1957
# - 2009_2127 merged into 2009_2125
#         '2009_5224' note eq to '2009_7086'
# - 2013_4179 merged into 2013_4365
#
# - 2007_4737 merged into 2007_4730
# - 2007_8121 merged into 2007_8120
# - 2015_3984 merged into 2015_3968
# - 2011_9524 merged into 2011_9537
# - 2011_9726 merged into 2011_9722
# - 2009_2255 merged into 2009_2256
# - 2009_4723 merged into 2009_4724
# - 2010_4123 merged into 2010_4124
# - 2010_6123 merged into 2010_6133
# - 2010_7596 merged into 2010_7597
#
# 109321 less 22 equals 109299.

# %%
# Review of the Cluster Points dataset to perform changes in cluster references that were made in the centerpoint review above. 
print(ClusterPoints.shape)
print(len(ClusterPoints['cluster_reference'].unique()))
ClusterPoints.head(1)

# %%
# Method to replace the first reference with the second in the cluster points data. 
ClusterPoints['cluster_reference'].mask(ClusterPoints['cluster_reference'] == '2004_5765', '2004_5772', inplace=True)

# %%
print(ClusterPoints.shape) # Check to confirm you removed the cluster reference that was moved into the new reference label. 
ClusterPoints.loc[(ClusterPoints['cluster_reference'] == '2006_1874')]
# Out:
# (5960572, 5)
# Empty DataFrame
# Columns: [latitude, longitude, ClusterNum, year, cluster_reference]
# Index: []

# %%
ClusterPoints.reset_index(inplace = True, drop = True)

# %% [markdown]
# ## Save updated Cluster Points data into new Dataframe/CSV for further use.

# %%
# Save new cluster points file into CSV. 
ClusterPoints.to_csv('../data/clusterpoints_03_15_refv5.17.csv', encoding='utf-8')

# %% [markdown]
# ### Remove centerpoint rows for duplicate cluster references as noted above.

# %%
fire_centerpoints.shape

# %%
adrop = '2010_7596'  # Cycle through centerpoint cluster references that need to be removed.

# %%
fire_centerpoints.drop(FireCenterPoints[FireCenterPoints['cluster_reference'] == adrop].index, inplace = True) # Cycle through centerpoint cluster references that need to be removed.

# %%
fire_centerpoints.shape

# %%
fire_centerpoints.reset_index(inplace = True, drop = True)

# %%
fire_centerpoints.to_csv('../data/Emissions Cluster Data/centerpoints_03_15_v5.csv', encoding='utf-8') # Save new centerpoints data to csv.

# %% [markdown]
# ----
# ----

# %% [markdown]
# # Assigning Cluster References to the Emissions Dataset:

# %%
# Bringing back up Emissions Data and removing first column. 
print(emdata_0315.shape)
emdata_0315 = emdata_0315.drop(columns=['Unnamed: 0'])
emdata_0315.head(2)
# Out:
# (5960572, 20)
#    index  year  doy  longitude  latitude  covertype  fuelcode  area_burned  \
# 0      0  2008  359   -81.0384   25.1958          3      1600          0.0
# 1      1  2008  359   -81.0404   25.1984          3      1600      62500.0
#
#    prefire_fuel  consumed_fuel         ECO2         ECO      ECH4     EPM2.5  \
# 0   6220.097576     1999.75772  3347.594423  153.981344  4.499455  23.797117
# 1   6220.097576     2041.37434  3417.260644  157.185824  4.593092  24.292355
#
#    cwd_frac  duff_frac  fuel_moisture_class  burnday_source  BSEV
# 0  0.023231   0.082115                    3              81     1
# 1  0.022757   0.080441                    3              81     2

# %% [markdown]
# ### Merge of Cluster Reference to Emissions Data:
# Taking the Emissions Dataset (emdata_0315) and by lat/long/year, bringing over the cluster references from the ClusterPoints df.

# %%
ClusterPoints2 = pd.read_csv('../data/clusterpoints_03_15_refv5.17.csv', encoding='utf-8')  # Taking new cluster points file created above, to then assign reference over to Emissions records.

# %%
# Checking dataframes.
print(emdata_0315.shape)
print(ClusterPoints.shape)
# Out:
# (5960572, 19)
# (5960572, 5)

# %%
ClusterPoints2.tail(5)
# Out:
#          Unnamed: 0  latitude  longitude  ClusterNum  year cluster_reference
# 5960567     5960567   48.8939  -121.1569        9262  2008         2008_9262
# 5960568     5960568   48.8945  -121.1537        9262  2008         2008_9262
# 5960569     5960569   48.8951  -121.1504        9262  2008         2008_9262
# 5960570     5960570   48.8967  -121.1545        9262  2008         2008_9262
# 5960571     5960571   48.9108  -122.0411        9263  2008         2008_9263

# %%
# New number of centerpoints per labels in cluster point df due to merging close centerpoints. 
clustercount = len(ClusterPoints2['cluster_reference'].unique())
print(clustercount)
# Out:
# 109299

# %%
ClusterPoints2_nodupe = ClusterPoints2.drop_duplicates(subset=['year', 'longitude', 'latitude'], keep='first')  # Taking out duplicates from cluster points records.

# %%
clustercount2 = len(ClusterPoints2_nodupe['cluster_reference'].unique())
print(clustercount2)
print(ClusterPoints2_nodupe['cluster_reference'].nunique())
# Out:
# 109299
# 109299

# %% [markdown]
# ### Remove duplicate records from Emissions dataset.

# %%
emdata_0315_nodup = emdata_0315.drop_duplicates(subset=['doy', 'year', 'longitude', 'latitude'], keep='first')

# %%
print(emdata_0315_nodup.shape)
emdata_0315_nodup[0:2]
# Out:
# (5936438, 19)
#    Unnamed: 0  year  doy  longitude  latitude  covertype  fuelcode  \
# 0           0  2008  359   -81.0384   25.1958          3      1600
# 1           1  2008  359   -81.0404   25.1984          3      1600
#
#    area_burned  prefire_fuel  consumed_fuel         ECO2         ECO  \
# 0          0.0   6220.097576     1999.75772  3347.594423  153.981344
# 1      62500.0   6220.097576     2041.37434  3417.260644  157.185824
#
#        ECH4     EPM2.5  cwd_frac  duff_frac  fuel_moisture_class  \
# 0  4.499455  23.797117  0.023231   0.082115                    3
# 1  4.593092  24.292355  0.022757   0.080441                    3
#
#    burnday_source  BSEV
# 0              81     1
# 1              81     2

# %%
# Merge over cluster reference from underlying cluster points records to the original Emissions dataset. 
emdata_0315_ref5 = emdata_0315_nodup.merge(right=ClusterPoints.loc[:,['latitude', 'longitude','year','cluster_reference']],
                   how='left',
                   left_on=['latitude','longitude','year'],
                   right_on=['latitude','longitude','year'])

# %%
print(emdata_0315_ref5.shape)
emdata_0315_ref5[0:3]
# Out:
# (5990537, 20)
#    Unnamed: 0  year  doy  longitude  latitude  covertype  fuelcode  \
# 0           0  2008  359   -81.0384   25.1958          3      1600
# 1           1  2008  359   -81.0404   25.1984          3      1600
# 2           2  2008  359   -81.0380   25.1981          3      1600
#
#    area_burned  prefire_fuel  consumed_fuel         ECO2         ECO  \
# 0          0.0   6220.097576     1999.75772  3347.594423  153.981344
# 1      62500.0   6220.097576     2041.37434  3417.260644  157.185824
# 2          0.0   6220.097576     1999.75772  3347.594423  153.981344
#
#        ECH4     EPM2.5  cwd_frac  duff_frac  fuel_moisture_class  \
# 0  4.499455  23.797117  0.023231   0.082115                    3
# 1  4.593092  24.292355  0.022757   0.080441                    3
# 2  4.499455  23.797117  0.023231   0.082115                    3
#
#    burnday_source  BSEV cluster_reference
# 0              81     1            2008_0
# 1              81     2            2008_0
# 2              81     1            2008_0

# %%
emdata_0315_ref5_clean = emdata_0315_ref5.drop_duplicates(subset=['doy', 'year', 'longitude', 'latitude'], keep='first')  # Remove duplicates after merge. 
print(emdata_0315_ref5_clean.shape)
# Out:
# (5936438, 20)

# %%
# Review of cluster references assigned to Emissions records. Noted that 135 centerpoint references did not port over, however, all records did receive a label. 
emclustercount2 = len(emdata_0315_ref5_clean['cluster_reference'].unique())
print(emclustercount2)
# Out:
# 109164

# %%
emdata_0315_ref5_clean.head()
# Out:
#    Unnamed: 0  year  doy  longitude  latitude  covertype  fuelcode  \
# 0           0  2008  359   -81.0384   25.1958          3      1600
# 1           1  2008  359   -81.0404   25.1984          3      1600
# 2           2  2008  359   -81.0380   25.1981          3      1600
# 3           4  2008  359   -81.0594   25.2035          3      1600
# 4           5  2008  359   -81.0570   25.2032          3      1600
#
#    area_burned  prefire_fuel  consumed_fuel         ECO2         ECO  \
# 0          0.0   6220.097576     1999.75772  3347.594423  153.981344
# 1      62500.0   6220.097576     2041.37434  3417.260644  157.185824
# 2          0.0   6220.097576     1999.75772  3347.594423  153.981344
# 3          0.0   6220.097576     1999.75772  3347.594423  153.981344
# 4      62500.0   6220.097576     2041.37434  3417.260644  157.185824
#
#        ECH4     EPM2.5  cwd_frac  duff_frac  fuel_moisture_class  \
# 0  4.499455  23.797117  0.023231   0.082115                    3
# 1  4.593092  24.292355  0.022757   0.080441                    3
# 2  4.499455  23.797117  0.023231   0.082115                    3
# 3  4.499455  23.797117  0.023231   0.082115                    3
# 4  4.593092  24.292355  0.022757   0.080441                    3
#
#    burnday_source  BSEV cluster_reference
# 0              81     1            2008_0
# 1              81     2            2008_0
# 2              81     1            2008_0
# 3              81     1            2008_0
# 4              81     2            2008_0

# %% [markdown]
# thirdcol = emdata_0315_ref5_clean.pop('cluster_reference')
# emdata_0315_ref5_clean.insert(2, 'cluster_reference', thirdcol)
# emdata_0315_ref5_clean[0:20]

# %%
emdata_0315_ref5_clean.tail()
# Out:
#          Unnamed: 0  year  doy  longitude  latitude  covertype  fuelcode  \
# 5936433     7254529  2003  181  -119.3634   48.9603          1         1
# 5936434     7254530  2003  182  -119.3602   48.9609          2         2
# 5936435     7254531  2003  181  -119.3642   48.9625          2         2
# 5936436     7254532  2003  182  -119.3610   48.9631          2         2
# 5936437     7254533  2003  219  -121.9887   48.5002          3      1200
#
#          area_burned  prefire_fuel  consumed_fuel         ECO2         ECO  \
# 5936433      62500.0    115.560666     107.471419   180.229570    7.522999
# 5936434          0.0    359.235630     323.312067   542.194336   22.631845
# 5936435      62500.0    324.937314     292.443583   490.427888   20.471051
# 5936436      62500.0    130.356018     117.320416   196.746338    8.212429
# 5936437      62500.0   6424.431099    4040.568775  6279.043877  537.395647
#
#               ECH4     EPM2.5  cwd_frac  duff_frac  fuel_moisture_class  \
# 5936433   0.288023   1.096208  0.000000   0.000000                    2
# 5936434   0.866476   3.297783  0.000000   0.000000                    2
# 5936435   0.783749   2.982925  0.000000   0.000000                    2
# 5936436   0.314419   1.196668  0.000000   0.000000                    2
# 5936437  30.223454  92.124968  0.236728   0.198929                    3
#
#          burnday_source  BSEV cluster_reference
# 5936433              77     2          2003_428
# 5936434              77     1          2003_428
# 5936435              77     2          2003_428
# 5936436              77     3          2003_428
# 5936437              77     3         2003_6230

# %%
emdata_0315_ref5_clean.reset_index(inplace = True, drop = True)

# %%
# Save emissions records to CSV for future model build. 
emdata_0315_ref5_clean.to_csv('/Users/AlfHaugen/Python/Wildfire_Data/FireExports/Emissions Cluster Data/emissions_03_15_v522.csv', encoding='utf-8')

# %% [markdown]
# ---

# %% [markdown]
# # Assign Cluster Reference to NASA M6 Data:

# %%
NASA_M6 = pd.read_sql(queryNASA, engine)  # Bring in NASA records from database.

# %% [raw]
# NASA_M6 = pd.read_csv('../data/fire_archive_M6_110066.csv') # Pull from disk if needed.

# %%
# Import file from K-D Tree 'Connect_Datasets_Clusters notebook' that has the cluster reference assigned to the lat/long and year for the NASA M6 records. 
NASA_M6_Cluster = pd.read_csv('../data/NASA_M6_ClusterRef_0315.csv')

# %%
# Assign the DOY, Month and Year from the Acq Date:

#NASA_M6['doy'] = pd.DatetimeIndex(NASA_M6['acq_date']).day
NASA_M6['datetime'] = pd.to_datetime(NASA_M6['acq_date'], infer_datetime_format=True)
NASA_M6['doy'] = NASA_M6['datetime'].dt.dayofyear
NASA_M6['month'] = pd.DatetimeIndex(NASA_M6['acq_date']).month
NASA_M6['year'] = pd.DatetimeIndex(NASA_M6['acq_date']).year

# %%
print(NASA_M6.shape)
NASA_M6.head()
# Out:
# (2159441, 12)
#    Key cluster_ref      lat       lon  brightness   acq_date acq_time  \
# 0    1   2003_1980  38.8142  -93.5539       300.8 2003-01-01 00:04:23
# 1    2     unknown  19.3739 -155.1130       318.8 2003-01-01 00:09:14
# 2    3     unknown  19.3723 -155.1197       316.0 2003-01-01 00:09:14
# 3    4     unknown  19.3589 -155.1107       325.2 2003-01-01 00:09:14
# 4    5     unknown  19.3573 -155.1174       319.0 2003-01-01 00:09:14
#
#    bright_t31    frp daynight  year  doy
# 0       267.0   10.4        N  2003    1
# 1       288.7   98.4        N  2003    1
# 2       288.3   85.0        N  2003    1
# 3       292.0  131.8        N  2003    1
# 4       290.3   97.3        N  2003    1

# %%
# Select only those NASA M6 records where the record was within 150 euclidean distance to the cluster that was assigned to it (or approx. 2.6km).
# This will reduce the number of NASA M6 records to be deployed in the model. 

NASA_M6_Cluster_under150 = NASA_M6_Cluster[NASA_M6_Cluster['distance'] < 150]
NASA_M6_Cluster_under150.shape
# Out:
# (1366022, 12)

# %%
NASA_M6_Cluster_under150 = NASA_M6_Cluster_under150.rename(columns={'source_lat': 'latitude', 'source_long': 'longitude', 'source_year': 'year','source_doy':'doy'}) # rename columns.
NASA_M6_Cluster_under150.head(20)
# Out:
#    Unnamed: 0  latitude  longitude  year  doy   distance  resultrow  \
# 0           0   31.2482   -85.7553  2004    1  31.187321       6628
# 1           1   35.4981   -78.1687  2004    1  25.878173      11904
# 2           2   35.4299   -77.3891  2004    1  51.303730      11805
# 3           3   31.7169   -81.8174  2004    1  25.301232        446
# 4           4   32.1135   -83.5330  2004    1  43.224914       7221
#
#    targetlat  targetlong  target_doy  target_year target_clusterref
# 0    31.7278    -85.7461           8         2004         2004_3025
# 1    35.8510    -78.1843           7         2004         2004_5314
# 2    35.2661    -77.1672          24         2004         2004_5256
# 3    32.0002    -81.6341           5         2004         2004_1108
# 4    32.0524    -83.2523          18         2004         2004_3253

# %%
NASA_M6_v2 = NASA_M6.merge(right=NASA_M6_Cluster_under150.loc[:,['latitude', 'longitude','year','doy', 'target_clusterref']],
                   how='left',
                   left_on=['latitude','longitude','year', 'doy'],
                   right_on=['latitude','longitude','year', 'doy'])

# %%
print(NASA_M6_v2.shape)
NASA_M6_v2.head()
# Out:
# (2159502, 20)
#    latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0   38.8142   -93.5539       300.8   1.0    1.0  2003-01-01       423
# 1   19.3739  -155.1130       318.8   3.1    1.7  2003-01-01       914
# 2   19.3723  -155.1197       316.0   3.1    1.7  2003-01-01       914
# 3   19.3589  -155.1107       325.2   3.1    1.7  2003-01-01       914
# 4   19.3573  -155.1174       319.0   3.1    1.7  2003-01-01       914
#
#   satellite instrument  confidence  version  bright_t31    frp daynight  type  \
# 0     Terra      MODIS          33      6.2       267.0   10.4        N     0
# 1     Terra      MODIS          97      6.2       288.7   98.4        N     2
# 2     Terra      MODIS          90      6.2       288.3   85.0        N     2
# 3     Terra      MODIS         100      6.2       292.0  131.8        N     2
# 4     Terra      MODIS          97      6.2       290.3   97.3        N     2
#
#     datetime  doy  month  year target_clusterref
# 0 2003-01-01    1      1  2003         2003_1980
# 1 2003-01-01    1      1  2003               NaN
# 2 2003-01-01    1      1  2003               NaN
# 3 2003-01-01    1      1  2003               NaN
# 4 2003-01-01    1      1  2003               NaN

# %%
NASA_M6_v2.loc[NASA_M6_v2['target_clusterref'] == '2004_3071']  # Searching for a single cluster to double check assignment.
# Out:
#         latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 118735   32.3560   -97.8140       309.5   1.1    1.1  2004-02-02      1732
# 119373   32.0950   -97.4140       306.9   1.4    1.2  2004-02-07      1923
# 120047   32.6840   -98.3922       312.9   1.5    1.2  2004-02-16      1744
# 120300   32.6518   -98.5524       310.2   1.3    1.1  2004-02-17      2000
# 120303   32.5699   -97.5225       323.7   1.5    1.2  2004-02-17      2000
# 120305   32.5673   -97.5165       330.3   1.5    1.2  2004-02-17      2000
# 120306   32.5715   -97.5069       313.6   1.5    1.2  2004-02-17      2000
# 120516   32.6377   -98.3569       304.2   3.1    1.7  2004-02-18      1905
# 120517   32.6532   -98.3551       306.0   3.1    1.7  2004-02-18      1905
# 121361   32.8146   -98.5304       303.1   2.9    1.6  2004-02-21      1803
# 121362   32.8278   -98.5327       309.1   2.9    1.6  2004-02-21      1803
# 121363   32.8287   -98.5257       306.8   2.9    1.6  2004-02-21      1803
# 121623   32.2942   -97.9154       310.2   1.1    1.0  2004-02-21      1936
# 121626   32.2885   -97.9087       326.6   1.1    1.0  2004-02-21      1936
# 121627   32.2903   -97.8975       313.6   1.1    1.0  2004-02-21      1936
# 121632   32.2960   -97.9043       328.4   1.1    1.0  2004-02-21      1936
# 121701   33.0698   -98.3932       326.9   1.1    1.0  2004-02-21      1936
# 121702   33.0717   -98.3817       345.0   1.1    1.0  2004-02-21      1936
# 121704   32.8172   -98.5310       357.4   1.1    1.0  2004-02-21      1936
# 121706   32.8264   -98.5332       337.9   1.1    1.0  2004-02-21      1936
# 121712   32.8190   -98.5194       324.8   1.1    1.0  2004-02-21      1936
# 121716   32.8994   -98.0768       307.8   1.1    1.0  2004-02-21      1936
# 121844   33.0762   -98.3941       310.4   1.4    1.2  2004-02-22      1708
# 121845   33.0790   -98.3854       317.9   1.4    1.2  2004-02-22      1708
# 121846   33.0746   -98.3793       312.8   1.4    1.2  2004-02-22      1708
# 121863   32.6806   -98.2826       302.8   1.3    1.1  2004-02-22      1708
# 121864   32.4813   -98.4121       306.2   1.4    1.2  2004-02-22      1708
# 121866   32.4726   -98.4278       307.9   1.4    1.2  2004-02-22      1708
# 122454   33.0230   -98.5456       301.7   1.1    1.0  2004-02-26      1954
# 122710   32.2610   -97.7920       306.7   1.0    1.0  2004-02-27      1726
# ...          ...        ...         ...   ...    ...         ...       ...
# 135969   32.7997   -98.6003       318.6   3.6    1.8  2004-03-29      1642
# 135970   32.8060   -98.5557       306.0   3.6    1.8  2004-03-29      1642
# 135971   32.7972   -98.5624       310.7   3.6    1.8  2004-03-29      1642
# 135973   32.8083   -98.5940       323.4   3.6    1.8  2004-03-29      1642
# 135993   32.6579   -98.0639       305.1   3.3    1.7  2004-03-29      1643
# 136172   32.7949   -98.5910       382.3   1.1    1.0  2004-03-29      1954
# 136173   32.7963   -98.5795       323.2   1.1    1.0  2004-03-29      1954
# 136174   32.7934   -98.6025       322.0   1.1    1.0  2004-03-29      1954
# 136178   32.8957   -98.0918       316.2   1.1    1.1  2004-03-29      1954
# 136180   32.8042   -98.5927       335.6   1.1    1.0  2004-03-29      1954
# 136578   32.5818   -97.7662       313.6   1.0    1.0  2004-03-30      1725
# 136579   32.3562   -97.6226       316.3   1.0    1.0  2004-03-30      1725
# 136580   32.3578   -97.6333       319.5   1.0    1.0  2004-03-30      1725
# 136584   32.8990   -98.0860       317.1   1.0    1.0  2004-03-30      1725
# 136585   33.0309   -98.5378       328.7   1.0    1.0  2004-03-30      1725
# 136586   32.7327   -98.4551       320.4   1.0    1.0  2004-03-30      1725
# 136588   32.7416   -98.4532       328.9   1.0    1.0  2004-03-30      1725
# 136589   32.7431   -98.4638       312.5   1.0    1.0  2004-03-30      1725
# 136591   33.0383   -98.5255       314.9   1.0    1.0  2004-03-30      1725
# 136592   32.5390   -98.3338       313.0   1.0    1.0  2004-03-30      1725
# 137331   32.2189   -97.3750       324.2   1.0    1.0  2004-03-31      1941
# 138386   32.5242   -97.7905       320.8   1.1    1.0  2004-04-01      1713
# 140971   32.8799   -98.3431       304.2   1.5    1.2  2004-04-04      1744
# 140972   32.8769   -98.3272       309.7   1.5    1.2  2004-04-04      1744
# 143618   32.8893   -98.0854       317.0   1.0    1.0  2004-04-08      1719
# 143621   32.8347   -98.6227       311.2   1.0    1.0  2004-04-08      1719
# 144933   32.5845   -97.8044       304.8   1.3    1.1  2004-04-13      1738
# 145738   32.6299   -98.3783       314.1   1.1    1.0  2004-04-14      1954
# 148462   32.6492   -98.3941       312.4   1.1    1.1  2004-04-25      1936
# 148564   32.8039   -98.1823       307.5   1.3    1.1  2004-04-26      1707
#
#        satellite instrument  confidence  version  bright_t31    frp daynight  \
# 118735     Terra      MODIS          60      6.2       282.8   13.9        D
# 119373      Aqua      MODIS          64      6.2       287.8   13.4        D
# 120047     Terra      MODIS          73      6.2       287.4   22.7        D
# 120300      Aqua      MODIS          61      6.2       293.5   10.5        D
# 120303      Aqua      MODIS          81      6.2       296.4   31.8        D
# 120305      Aqua      MODIS          86      6.2       296.0   43.8        D
# 120306      Aqua      MODIS          69      6.2       294.8   15.6        D
# 120516      Aqua      MODIS          37      6.2       292.4   20.6        D
# 120517      Aqua      MODIS          54      6.2       292.5   28.2        D
# 121361     Terra      MODIS          46      6.2       290.3   19.3        D
# 121362     Terra      MODIS          63      6.2       290.9   38.4        D
# 121363     Terra      MODIS          62      6.2       290.8   31.1        D
# 121623      Aqua      MODIS          42      6.2       293.4    8.3        D
# 121626      Aqua      MODIS          85      6.2       293.2   24.6        D
# 121627      Aqua      MODIS          74      6.2       291.1   11.3        D
# 121632      Aqua      MODIS          65      6.2       292.6   27.2        D
# 121701      Aqua      MODIS          83      6.2       295.1   24.4        D
# 121702      Aqua      MODIS          93      6.2       295.4   55.0        D
# 121704      Aqua      MODIS          99      6.2       300.7   88.6        D
# 121706      Aqua      MODIS          90      6.2       297.8   41.8        D
# 121712      Aqua      MODIS          82      6.2       296.0   21.9        D
# 121716      Aqua      MODIS          53      6.2       291.6    7.0        D
# 121844     Terra      MODIS          61      6.2       293.6    9.8        D
# 121845     Terra      MODIS          76      6.2       293.7   19.4        D
# 121846     Terra      MODIS          69      6.2       293.2   12.6        D
# 121863     Terra      MODIS          32      6.2       289.5    5.5        D
# 121864     Terra      MODIS          45      6.2       291.8    6.9        D
# 121866     Terra      MODIS          31      6.2       290.6    9.0        D
# 122454      Aqua      MODIS          32      6.2       290.8    3.5        D
# 122710     Terra      MODIS          64      6.2       290.0    7.1        D
# ...          ...        ...         ...      ...         ...    ...      ...
# 135969     Terra      MODIS          76      6.2       293.2   85.8        D
# 135970     Terra      MODIS          51      6.2       293.5   29.1        D
# 135971     Terra      MODIS          42      6.2       293.2   44.2        D
# 135973     Terra      MODIS          80      6.2       294.1  121.6        D
# 135993     Terra      MODIS          48      6.2       294.8   20.1        D
# 136172      Aqua      MODIS         100      6.2       304.4  177.3        D
# 136173      Aqua      MODIS          71      6.2       298.6   15.5        D
# 136174      Aqua      MODIS          68      6.2       300.3   13.9        D
# 136178      Aqua      MODIS          57      6.2       302.2    8.2        D
# 136180      Aqua      MODIS          85      6.2       302.1   32.3        D
# 136578     Terra      MODIS          61      6.2       301.4    6.4        D
# 136579     Terra      MODIS          67      6.2       304.2    9.6        D
# 136580     Terra      MODIS          72      6.2       302.7   12.2        D
# 136584     Terra      MODIS          66      6.2       300.0    9.6        D
# 136585     Terra      MODIS          81      6.2       301.4   20.9        D
# 136586     Terra      MODIS          71      6.2       297.8   13.2        D
# 136588     Terra      MODIS          81      6.2       298.8   22.1        D
# 136589     Terra      MODIS          31      6.2       298.8    5.9        D
# 136591     Terra      MODIS          57      6.2       301.4    7.0        D
# 136592     Terra      MODIS          54      6.2       300.0    6.4        D
# 137331      Aqua      MODIS          73      6.2       306.0   13.8        D
# 138386     Terra      MODIS          69      6.2       302.4   13.0        D
# 140971     Terra      MODIS          55      6.2       269.6   12.9        D
# 140972     Terra      MODIS          69      6.2       269.2   19.0        D
# 143618     Terra      MODIS          67      6.2       298.1    9.8        D
# 143621     Terra      MODIS          47      6.2       298.7    4.6        D
# 144933     Terra      MODIS          53      6.2       293.6    6.1        D
# 145738      Aqua      MODIS          46      6.2       302.6    7.1        D
# 148462      Aqua      MODIS          55      6.2       296.9    7.9        D
# 148564     Terra      MODIS          35      6.2       295.0    5.4        D
#
#         type   datetime  doy  month  year target_clusterref
# 118735     0 2004-02-02   33      2  2004         2004_3071
# 119373     0 2004-02-07   38      2  2004         2004_3071
# 120047     0 2004-02-16   47      2  2004         2004_3071
# 120300     0 2004-02-17   48      2  2004         2004_3071
# 120303     0 2004-02-17   48      2  2004         2004_3071
# 120305     0 2004-02-17   48      2  2004         2004_3071
# 120306     0 2004-02-17   48      2  2004         2004_3071
# 120516     0 2004-02-18   49      2  2004         2004_3071
# 120517     0 2004-02-18   49      2  2004         2004_3071
# 121361     0 2004-02-21   52      2  2004         2004_3071
# 121362     0 2004-02-21   52      2  2004         2004_3071
# 121363     0 2004-02-21   52      2  2004         2004_3071
# 121623     0 2004-02-21   52      2  2004         2004_3071
# 121626     0 2004-02-21   52      2  2004         2004_3071
# 121627     0 2004-02-21   52      2  2004         2004_3071
# 121632     0 2004-02-21   52      2  2004         2004_3071
# 121701     0 2004-02-21   52      2  2004         2004_3071
# 121702     0 2004-02-21   52      2  2004         2004_3071
# 121704     0 2004-02-21   52      2  2004         2004_3071
# 121706     0 2004-02-21   52      2  2004         2004_3071
# 121712     0 2004-02-21   52      2  2004         2004_3071
# 121716     0 2004-02-21   52      2  2004         2004_3071
# 121844     0 2004-02-22   53      2  2004         2004_3071
# 121845     0 2004-02-22   53      2  2004         2004_3071
# 121846     0 2004-02-22   53      2  2004         2004_3071
# 121863     0 2004-02-22   53      2  2004         2004_3071
# 121864     0 2004-02-22   53      2  2004         2004_3071
# 121866     0 2004-02-22   53      2  2004         2004_3071
# 122454     0 2004-02-26   57      2  2004         2004_3071
# 122710     0 2004-02-27   58      2  2004         2004_3071
# ...      ...        ...  ...    ...   ...               ...
# 135969     0 2004-03-29   89      3  2004         2004_3071
# 135970     0 2004-03-29   89      3  2004         2004_3071
# 135971     0 2004-03-29   89      3  2004         2004_3071
# 135973     0 2004-03-29   89      3  2004         2004_3071
# 135993     0 2004-03-29   89      3  2004         2004_3071
# 136172     0 2004-03-29   89      3  2004         2004_3071
# 136173     0 2004-03-29   89      3  2004         2004_3071
# 136174     0 2004-03-29   89      3  2004         2004_3071
# 136178     0 2004-03-29   89      3  2004         2004_3071
# 136180     0 2004-03-29   89      3  2004         2004_3071
# 136578     0 2004-03-30   90      3  2004         2004_3071
# 136579     0 2004-03-30   90      3  2004         2004_3071
# 136580     0 2004-03-30   90      3  2004         2004_3071
# 136584     0 2004-03-30   90      3  2004         2004_3071
# 136585     0 2004-03-30   90      3  2004         2004_3071
# 136586     0 2004-03-30   90      3  2004         2004_3071
# 136588     0 2004-03-30   90      3  2004         2004_3071
# 136589     0 2004-03-30   90      3  2004         2004_3071
# 136591     0 2004-03-30   90      3  2004         2004_3071
# 136592     0 2004-03-30   90      3  2004         2004_3071
# 137331     0 2004-03-31   91      3  2004         2004_3071
# 138386     0 2004-04-01   92      4  2004         2004_3071
# 140971     0 2004-04-04   95      4  2004         2004_3071
# 140972     0 2004-04-04   95      4  2004         2004_3071
# 143618     0 2004-04-08   99      4  2004         2004_3071
# 143621     0 2004-04-08   99      4  2004         2004_3071
# 144933     0 2004-04-13  104      4  2004         2004_3071
# 145738     0 2004-04-14  105      4  2004         2004_3071
# 148462     0 2004-04-25  116      4  2004         2004_3071
# 148564     0 2004-04-26  117      4  2004         2004_3071
#
# [100 rows x 20 columns]

# %%
# Review of any duplicates. 
dupes5 = NASA_M6_v2[NASA_M6_v2.duplicated(['doy', 'year', 'longitude', 'latitude'],keep = False)]

# %%
dupes5[0:4] # Review of any duplicates.
# Out:
#        latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 67555   44.5066  -121.7679       324.6   1.4    1.2  2003-08-24       951
# 67556   44.5066  -121.7679       324.6   1.4    1.2  2003-08-24       951
# 67673   44.5066  -121.7679       340.8   1.1    1.0  2003-08-24      2058
# 67674   44.5066  -121.7679       340.8   1.1    1.0  2003-08-24      2058
#
#       satellite instrument  confidence  version  bright_t31   frp daynight  \
# 67555      Aqua      MODIS          10      6.2       285.5  33.1        N
# 67556      Aqua      MODIS          10      6.2       285.5  33.1        N
# 67673      Aqua      MODIS          39      6.2       299.2  39.1        D
# 67674      Aqua      MODIS          39      6.2       299.2  39.1        D
#
#        type   datetime  doy  month  year target_clusterref
# 67555     0 2003-08-24  236      8  2003          2003_328
# 67556     0 2003-08-24  236      8  2003          2003_328
# 67673     0 2003-08-24  236      8  2003          2003_328
# 67674     0 2003-08-24  236      8  2003          2003_328

# %%
# Remove duplicates after merge between NASA M6 records and the records with the cluster reference assigned that were <150 euclidean distance. 
NASA_M6_v2 = NASA_M6_v2.drop_duplicates(subset=['doy', 'year', 'longitude', 'latitude'], keep='first')
print(NASA_M6_v2.shape)
# Out:
# (2159441, 20)

# %%
# Save new NASA M6 dataset with complete cluster reference assignment. 
NASA_M6_v2.to_csv('../data/NASA_M6_FullData_ClusterRef_May30.csv')

# %% [markdown]
# ### DBScan Visual

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Setting color scheme. 
alfs_colors = ['#281555', "#9b59b6", '#575f8a', '#95a5a6', "#e74c3c", '#CC4B34', "#2ecc71", "#34495e", '#3040ba', "#3498db", '#0377A8']

sns.set_palette(sns.color_palette(alfs_colors))
sns.palplot(sns.color_palette(alfs_colors))

# %%
NASA_Emissions_ClusterDetail = pd.read_csv('../data/nasa_emissions_doycombined_May28.csv')

# %%
print(NASA_Emissions_ClusterDetail.shape)
NASA_Emissions_ClusterDetail.head(20)
# Out:
# (727866, 8)
#     Unnamed: 0  year cluster_reference  cluster_doy  doy_count  \
# 0            0  2003            2003_0           95          2
# 1            1  2003            2003_0           97          7
# 2       318540  2003            2003_0           98          6
# 3            2  2003            2003_0           98          5
# 4            3  2003            2003_0           99          1
# 5       318541  2003            2003_0          100          2
# 6            4  2003            2003_0          100         17
# 7            5  2003            2003_0          101          3
# 8            6  2003            2003_0          102          3
# 9            7  2003            2003_0          105          8
# 10           8  2003            2003_0          107          4
# 11      318542  2003            2003_0          128         11
# 12      318543  2003            2003_0          129          1
# 13      318544  2003            2003_0          130         18
# 14           9  2003            2003_0          130         99
# 15      318545  2003            2003_0          131          1
# 16          10  2003            2003_0          131         13
# 17      318546  2003            2003_0          139          1
# 18      318547  2003            2003_1          197          2
# 19          11  2003            2003_1          206          4
#
#     centerpoint_doy  longitude  latitude
# 0             131.0    -80.686   25.4148
# 1             131.0    -80.686   25.4148
# 2             131.0    -80.686   25.4148
# 3             131.0    -80.686   25.4148
# 4             131.0    -80.686   25.4148
# 5             131.0    -80.686   25.4148
# 6             131.0    -80.686   25.4148
# 7             131.0    -80.686   25.4148
# 8             131.0    -80.686   25.4148
# 9             131.0    -80.686   25.4148
# 10            131.0    -80.686   25.4148
# 11            131.0    -80.686   25.4148
# 12            131.0    -80.686   25.4148
# 13            131.0    -80.686   25.4148
# 14            131.0    -80.686   25.4148
# 15            131.0    -80.686   25.4148
# 16            131.0    -80.686   25.4148
# 17            131.0    -80.686   25.4148
# 18            209.0    -80.930   25.4582
# 19            209.0    -80.930   25.4582

# %%
c_max = NASA_Emissions_ClusterDetail.groupby(["year", "cluster_reference"], as_index=False)["cluster_doy"].max()
c_min = NASA_Emissions_ClusterDetail.groupby(["year", "cluster_reference"], as_index=False)["cluster_doy"].min()
c_median = NASA_Emissions_ClusterDetail.groupby(["year", "cluster_reference"], as_index=False)["cluster_doy"].mean()
c_doy = NASA_Emissions_ClusterDetail.groupby(["year", "cluster_reference"], as_index=False)["cluster_doy"].count()

# %%
c_doy_sum = NASA_Emissions_ClusterDetail.groupby(["year", "cluster_reference"], as_index=False)["doy_count"].sum()

# %% [raw]
# ccount = NASA_Emissions_ClusterDetail.groupby(["year", "cluster_reference"], as_index=False)["cluster_doy"].nunique()
# ccount = pd.DataFrame(ccount)

# %% [raw]
# ccount.head()

# %%
c_doy = c_doy.rename(columns = {'total_doy_count':'doycount_cluster'})

# %%
c_doy.head()
# Out:
#    year cluster_reference  doycount_cluster
# 0  2003            2003_0                18
# 1  2003            2003_1                19
# 2  2003           2003_10                 9
# 3  2003          2003_100                64
# 4  2003         2003_1000                 1

# %%
c_doy['doy_max'] = c_max['cluster_doy']

# %%
c_doy['doy_min'] = c_min['cluster_doy']

# %%
c_doy['clusterpoint_sum'] = c_doy_sum['doy_count']

# %%
print(c_doy.shape)
c_doy.head(20)
# Out:
# (109163, 6)
#     year cluster_reference  doycount_cluster  doy_max  doy_min  \
# 0   2003            2003_0                18      139       95
# 1   2003            2003_1                19      228      197
# 2   2003           2003_10                 9      358      328
# 3   2003          2003_100                64      362      248
# 4   2003         2003_1000                 1      107      107
# 5   2003         2003_1001                12      311      282
# 6   2003         2003_1002                 8      161      116
# 7   2003         2003_1003                 9      365      341
# 8   2003         2003_1004                 2      104       91
# 9   2003         2003_1005                 5      108       83
# 10  2003         2003_1006                 1      106      106
# 11  2003         2003_1007                 2      282      281
# 12  2003         2003_1008                 8       21        7
# 13  2003         2003_1009                12      149       92
# 14  2003          2003_101                52      296      185
# 15  2003         2003_1010                18      291      228
# 16  2003         2003_1011                15      209      142
# 17  2003         2003_1012                40      278      209
# 18  2003         2003_1013                17      317      277
# 19  2003         2003_1014                 5      191      148
#
#     clusterpoint_sum
# 0                202
# 1                 38
# 2                 39
# 3              10342
# 4                  5
# 5                 32
# 6                 14
# 7                 16
# 8                  4
# 9                  5
# 10                 2
# 11                 6
# 12               117
# 13                62
# 14               113
# 15                34
# 16                28
# 17               229
# 18                40
# 19                28

# %%
cluster_visual = c_doy.merge(right=NASA_Emissions_ClusterDetail.loc[:,['year','cluster_reference', 'longitude', 'latitude']],
                   how='left',
                   left_on=['year','cluster_reference'],
                   right_on=['year','cluster_reference'])

# %%
print(cluster_visual.shape)
cluster_visual.head(20)
# Out:
# (109163, 8)
#      year cluster_reference  doycount_cluster  doy_max  doy_min  \
# 0    2003            2003_0                18      139       95
# 18   2003            2003_1                19      228      197
# 37   2003           2003_10                 9      358      328
# 46   2003          2003_100                64      362      248
# 110  2003         2003_1000                 1      107      107
# 111  2003         2003_1001                12      311      282
# 123  2003         2003_1002                 8      161      116
# 131  2003         2003_1003                 9      365      341
# 140  2003         2003_1004                 2      104       91
# 142  2003         2003_1005                 5      108       83
# 147  2003         2003_1006                 1      106      106
# 148  2003         2003_1007                 2      282      281
# 150  2003         2003_1008                 8       21        7
# 158  2003         2003_1009                12      149       92
# 170  2003          2003_101                52      296      185
# 222  2003         2003_1010                18      291      228
# 240  2003         2003_1011                15      209      142
# 255  2003         2003_1012                40      278      209
# 295  2003         2003_1013                17      317      277
# 312  2003         2003_1014                 5      191      148
#
#      clusterpoint_sum  longitude  latitude
# 0                 202   -80.6860   25.4148
# 18                 38   -80.9300   25.4582
# 37                 39   -94.1279   29.7238
# 46              10342  -117.3717   34.2190
# 110                 5   -91.7724   30.5503
# 111                32   -91.5838   30.5586
# 123                14   -91.8531   30.5578
# 131                16   -91.4775   30.5430
# 140                 4   -91.7867   30.5778
# 142                 5   -91.8645   30.5898
# 147                 2   -91.8252   30.5928
# 148                 6   -91.5719   30.5852
# 150               117   -84.6271   30.1074
# 158                62   -84.3787   30.0699
# 170               113   -85.0220   35.5589
# 222                34   -91.4947   30.6091
# 240                28   -91.2790   30.5843
# 255               229   -93.0048   30.6514
# 295                40   -91.9362   30.6217
# 312                28   -88.6625   30.4545

# %%
cluster_visual = cluster_visual.drop_duplicates(subset=['year', 'cluster_reference'], keep='first')

# %%
cluster_visual.to_csv('../data/DBScan_VisualDF_Pre.csv')

# %%
DBScan_VisualDF = pd.read_csv('../data/DBScan_VisualDF.csv')

# %%
DBScan_VisualDF = DBScan_VisualDF.rename(columns = {'cluster_doy':'Range of Days in Cluster', 'clusterpoint_sum': 'Count of Fire Data Points'})

# %%
DBScan_VisualDF.head()
# Out:
#    Unnamed: 0  year cluster_reference  Range of Days in Cluster  doy_max  \
# 0           0  2003            2003_0                        18      139
# 1          18  2003            2003_1                        19      228
# 2          37  2003           2003_10                         9      358
# 3          46  2003          2003_100                        64      362
# 4         110  2003         2003_1000                         1      107
#
#    doy_min  Count of Fire Data Points  longitude  latitude
# 0       95                        202   -80.6860   25.4148
# 1      197                         38   -80.9300   25.4582
# 2      328                         39   -94.1279   29.7238
# 3      248                      10342  -117.3717   34.2190
# 4      107                          5   -91.7724   30.5503

# %% [markdown]
# ---
# ### Plotting

# %%
WashSt = DBScan_VisualDF[(DBScan_VisualDF.latitude < 48.9) & (DBScan_VisualDF.latitude > 45.4) & (DBScan_VisualDF.longitude > -124.89) & (DBScan_VisualDF.longitude < -116.98)]

# %%
import seaborn as sns
sns.set_style("white")
plt.figure(figsize=(16, 10))

cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)

ax = sns.scatterplot(x="longitude", y="latitude",
                     hue="Range of Days in Cluster", size="Count of Fire Data Points",
                     palette='Reds',edgecolor='Grey', linewidth=.03, alpha=.75, sizes=(40, 1400),
                     data=WashSt)
plt.title('Washington State Fire Event Clusters 2003-2015')
plt.legend(loc='center right', bbox_to_anchor=(1.22, 0.5), fontsize = 12, labelspacing=2.5)

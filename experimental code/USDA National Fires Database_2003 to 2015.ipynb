# %%
import sqlite3
import pandas as pd

# %% [markdown]
# ### Connect to National Fires Database
# Data Source: https://www.fs.usda.gov/rds/archive/catalog/RDS-2013-0009.4
# USDA Data Description: https://www.fs.fed.us/rm/pubs_other/rmrs_2014_short_k001.pdf

# %%
firedata1 = 'RDS-2013-0009.4_SQLITE/Data/FPA_FOD_20170508.sqlite'

# %%
conn = sqlite3.connect(firedata1)

# %% [markdown]
# ### Print All Table Names

# %%
cursor = conn.cursor()

# %%
sql = '''SELECT 
    name
FROM 
    sqlite_master 
WHERE 
    type ='table'
    '''

# %%
cursor.execute(sql)

# %%
cursor.fetchall()
# Out:
# [('spatial_ref_sys',),
#  ('spatialite_history',),
#  ('sqlite_sequence',),
#  ('geometry_columns',),
#  ('spatial_ref_sys_aux',),
#  ('views_geometry_columns',),
#  ('virts_geometry_columns',),
#  ('geometry_columns_statistics',),
#  ('views_geometry_columns_statistics',),
#  ('virts_geometry_columns_statistics',),
#  ('geometry_columns_field_infos',),
#  ('views_geometry_columns_field_infos',),
#  ('virts_geometry_columns_field_infos',),
#  ('geometry_columns_time',),
#  ('geometry_columns_auth',),
#  ('views_geometry_columns_auth',),
#  ('virts_geometry_columns_auth',),
#  ('sql_statements_log',),
#  ('SpatialIndex',),
#  ('ElementaryGeometries',),
#  ('KNN',),
#  ('Fires',),
#  ('idx_Fires_Shape',),
#  ('idx_Fires_Shape_node',),
#  ('idx_Fires_Shape_rowid',),
#  ('idx_Fires_Shape_parent',),
#  ('NWCG_UnitIDActive_20170109',)]

# %% [markdown]
# ### Read as Data Frame

# %%
sql = "select * from fires"
df = pd.read_sql(sql, conn)
df.head()
# Out:
#    OBJECTID  FOD_ID      FPA_ID SOURCE_SYSTEM_TYPE SOURCE_SYSTEM  \
# 0         1       1  FS-1418826                FED   FS-FIRESTAT
# 1         2       2  FS-1418827                FED   FS-FIRESTAT
# 2         3       3  FS-1418835                FED   FS-FIRESTAT
# 3         4       4  FS-1418845                FED   FS-FIRESTAT
# 4         5       5  FS-1418847                FED   FS-FIRESTAT
#
#   NWCG_REPORTING_AGENCY NWCG_REPORTING_UNIT_ID  NWCG_REPORTING_UNIT_NAME  \
# 0                    FS                USCAPNF    Plumas National Forest
# 1                    FS                USCAENF  Eldorado National Forest
# 2                    FS                USCAENF  Eldorado National Forest
# 3                    FS                USCAENF  Eldorado National Forest
# 4                    FS                USCAENF  Eldorado National Forest
#
#   SOURCE_REPORTING_UNIT SOURCE_REPORTING_UNIT_NAME  ... FIRE_SIZE_CLASS  \
# 0                  0511     Plumas National Forest  ...               A
# 1                  0503   Eldorado National Forest  ...               A
# 2                  0503   Eldorado National Forest  ...               A
# 3                  0503   Eldorado National Forest  ...               A
# 4                  0503   Eldorado National Forest  ...               A
#
#     LATITUDE   LONGITUDE OWNER_CODE       OWNER_DESCR STATE COUNTY FIPS_CODE  \
# 0  40.036944 -121.005833        5.0              USFS    CA     63       063
# 1  38.933056 -120.404444        5.0              USFS    CA     61       061
# 2  38.984167 -120.735556       13.0  STATE OR PRIVATE    CA     17       017
# 3  38.559167 -119.913333        5.0              USFS    CA      3       003
# 4  38.559167 -119.933056        5.0              USFS    CA      3       003
#
#    FIPS_NAME                                              Shape
# 0     Plumas  b'\x00\x01\xad\x10\x00\x00\xe8d\xc2\x92_@^\xc0...
# 1     Placer  b'\x00\x01\xad\x10\x00\x00T\xb6\xeej\xe2\x19^\...
# 2  El Dorado  b'\x00\x01\xad\x10\x00\x00\xd0\xa5\xa0W\x13/^\...
# 3     Alpine  b'\x00\x01\xad\x10\x00\x00\x94\xac\xa3\rt\xfa]...
# 4     Alpine  b'\x00\x01\xad\x10\x00\x00@\xe3\xaa.\xb7\xfb]\...
#
# [5 rows x 39 columns]

# %%
# df.to_csv('fires_db.csv')

# %%
# Subsetting to the state of California within fires_db

ca = df.loc[df['STATE'] == 'CA']

# %%
# A tuple that represents the fires_db dimensions:

ca.shape
# Out:
# (189550, 39)

# %%
# To see all of the column labels of the fires_db:

ca.columns
# Out:
# Index(['OBJECTID', 'FOD_ID', 'FPA_ID', 'SOURCE_SYSTEM_TYPE', 'SOURCE_SYSTEM',
#        'NWCG_REPORTING_AGENCY', 'NWCG_REPORTING_UNIT_ID',
#        'NWCG_REPORTING_UNIT_NAME', 'SOURCE_REPORTING_UNIT',
#        'SOURCE_REPORTING_UNIT_NAME', 'LOCAL_FIRE_REPORT_ID',
#        'LOCAL_INCIDENT_ID', 'FIRE_CODE', 'FIRE_NAME',
#        'ICS_209_INCIDENT_NUMBER', 'ICS_209_NAME', 'MTBS_ID', 'MTBS_FIRE_NAME',
#        'COMPLEX_NAME', 'FIRE_YEAR', 'DISCOVERY_DATE', 'DISCOVERY_DOY',
#        'DISCOVERY_TIME', 'STAT_CAUSE_CODE', 'STAT_CAUSE_DESCR', 'CONT_DATE',
#        'CONT_DOY', 'CONT_TIME', 'FIRE_SIZE', 'FIRE_SIZE_CLASS', 'LATITUDE',
#        'LONGITUDE', 'OWNER_CODE', 'OWNER_DESCR', 'STATE', 'COUNTY',
#        'FIPS_CODE', 'FIPS_NAME', 'Shape'],
#       dtype='object')

# %%
# To see the column labels that were not shown in previous table:

ca[['FIRE_NAME', 'STAT_CAUSE_DESCR', 'FIRE_YEAR', 'DISCOVERY_DATE', 'FIRE_SIZE', 'SOURCE_REPORTING_UNIT_NAME', 'LOCAL_FIRE_REPORT_ID', 'LOCAL_INCIDENT_ID', 'FIRE_CODE', 'ICS_209_INCIDENT_NUMBER', 'ICS_209_NAME', 'MTBS_ID', 'MTBS_FIRE_NAME', 'COMPLEX_NAME']].head()
# Out:
#   FIRE_NAME STAT_CAUSE_DESCR  FIRE_YEAR  DISCOVERY_DATE  FIRE_SIZE  \
# 0  FOUNTAIN    Miscellaneous       2005       2453403.5       0.10
# 1    PIGEON        Lightning       2004       2453137.5       0.25
# 2     SLACK   Debris Burning       2004       2453156.5       0.10
# 3      DEER        Lightning       2004       2453184.5       0.10
# 4  STEVENOT        Lightning       2004       2453184.5       0.10
#
#   SOURCE_REPORTING_UNIT_NAME LOCAL_FIRE_REPORT_ID LOCAL_INCIDENT_ID FIRE_CODE  \
# 0     Plumas National Forest                    1            PNF-47      BJ8K
# 1   Eldorado National Forest                   13                13      AAC0
# 2   Eldorado National Forest                   27               021      A32W
# 3   Eldorado National Forest                   43                 6      None
# 4   Eldorado National Forest                   44                 7      None
#
#   ICS_209_INCIDENT_NUMBER ICS_209_NAME MTBS_ID MTBS_FIRE_NAME COMPLEX_NAME
# 0                    None         None    None           None         None
# 1                    None         None    None           None         None
# 2                    None         None    None           None         None
# 3                    None         None    None           None         None
# 4                    None         None    None           None         None

# %%
# To see the data frame summary of columns and their data types:

ca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 189550 entries, 0 to 1880464
# Data columns (total 39 columns):
# OBJECTID                      189550 non-null int64
# FOD_ID                        189550 non-null int64
# FPA_ID                        189550 non-null object
# SOURCE_SYSTEM_TYPE            189550 non-null object
# SOURCE_SYSTEM                 189550 non-null object
# NWCG_REPORTING_AGENCY         189550 non-null object
# NWCG_REPORTING_UNIT_ID        189550 non-null object
# NWCG_REPORTING_UNIT_NAME      189550 non-null object
# SOURCE_REPORTING_UNIT         189550 non-null object
# SOURCE_REPORTING_UNIT_NAME    189550 non-null object
# LOCAL_FIRE_REPORT_ID          61933 non-null object
# LOCAL_INCIDENT_ID             127983 non-null object
# FIRE_CODE                     55533 non-null object
# FIRE_NAME                     174557 non-null object
# ICS_209_INCIDENT_NUMBER       2838 non-null object
# ICS_209_NAME                  2838 non-null object
# MTBS_ID                       1137 non-null object
# MTBS_FIRE_NAME                1137 non-null object
# COMPLEX_NAME                  927 non-null object
# FIRE_YEAR                     189550 non-null int64
# DISCOVERY_DATE                189550 non-null float64
# DISCOVERY_DOY                 189550 non-null int64
# DISCOVERY_TIME                110217 non-null object
# STAT_CAUSE_CODE               189550 non-null float64
# STAT_CAUSE_DESCR              189550 non-null object
# CONT_DATE                     91908 non-null float64
# CONT_DOY                      91908 non-null float64
# CONT_TIME                     91217 non-null object
# FIRE_SIZE                     189550 non-null float64
# FIRE_SIZE_CLASS               189550 non-null object
# LATITUDE                      189550 non-null float64
# LONGITUDE                     189550 non-null float64
# OWNER_CODE                    189550 non-null float64
# OWNER_DESCR                   189550 non-null object
# STATE                         189550 non-null object
# COUNTY                        56221 non-null object
# FIPS_CODE                     56221 non-null object
# FIPS_NAME                     56221 non-null object
# Shape                         189550 non-null object
# dtypes: float64(8), int64(4), object(27)
# memory usage: 57.8+ MB

# %%
# Confirming data in the forest fires_db from 1992 to 2015:

ca['FIRE_YEAR'].unique()
# Out:
# array([2005, 2004, 2006, 2002, 2007, 2008, 2009, 1992, 1993, 1994, 1995,
#        1996, 1997, 1998, 1999, 2000, 2001, 2003, 2010, 2011, 2012, 2013,
#        2014, 2015], dtype=int64)

# %%
# Checking the number of fire occurances in the fires_db (unique days of fire):

len(ca['DISCOVERY_DATE'].unique())
# Out:
# 8324

# %%
# Looking for the total number of occurences per stated cause of fire:

print(ca.groupby('STAT_CAUSE_DESCR').size())
# Out:
# STAT_CAUSE_DESCR
# Arson                19635
# Campfire              9516
# Children              6930
# Debris Burning       14318
# Equipment Use        39407
# Fireworks              219
# Lightning            27000
# Miscellaneous        51943
# Missing/Undefined    12605
# Powerline             1198
# Railroad               720
# Smoking               5936
# Structure              123
# dtype: int64

# %%
# Looking for the total number of occurences per year per stated cause of fire:

ca.groupby(['STAT_CAUSE_DESCR','FIRE_YEAR']).size()
# Out:
# STAT_CAUSE_DESCR  FIRE_YEAR
# Arson             1992         1155
#                   1993         1077
#                   1994          768
#                   1995          997
#                   1996          948
#                                ...
# Structure         2011            6
#                   2012           10
#                   2013            8
#                   2014           20
#                   2015            3
# Length: 309, dtype: int64

# %%
# The number of fire occurences per year per stated cause of fire for the state of CA:

ca.groupby(['STAT_CAUSE_DESCR','FIRE_YEAR']).size()
# Out:
# STAT_CAUSE_DESCR  FIRE_YEAR
# Arson             1992         1155
#                   1993         1077
#                   1994          768
#                   1995          997
#                   1996          948
#                                ...
# Structure         2011            6
#                   2012           10
#                   2013            8
#                   2014           20
#                   2015            3
# Length: 309, dtype: int64

# %%
ca.groupby('STAT_CAUSE_DESCR').max()
# Out:
#                    OBJECTID     FOD_ID   FPA_ID SOURCE_SYSTEM_TYPE  \
# STAT_CAUSE_DESCR
# Arson               1880458  300348354  W-99825             NONFED
# Campfire            1804572  300218047   W-9999             NONFED
# Children            1880454  300348297   W-9912             NONFED
# Debris Burning      1880453  300348293  W-99978             NONFED
# Equipment Use       1880452  300348291  W-99821             NONFED
# Fireworks           1797737  300209770   W-9917                FED
# Lightning           1880459  300348361   W-9959             NONFED
# Miscellaneous       1880465  300348399   W-9966             NONFED
# Missing/Undefined   1880464  300348377  W-91741             NONFED
# Powerline           1880225  300346883   W-9848             NONFED
# Railroad            1880393  300348033   W-9925             NONFED
# Smoking             1880402  300348051   W-9922             NONFED
# Structure           1797668  300209700  W-99976             NONFED
#
#                   SOURCE_SYSTEM NWCG_REPORTING_AGENCY NWCG_REPORTING_UNIT_ID  \
# STAT_CAUSE_DESCR
# Arson                   ST-NASF                ST/C&L                USNVHTF
# Campfire                ST-NASF                ST/C&L                USORRSF
# Children                ST-NASF                ST/C&L                USNVHTF
# Debris Burning          ST-NASF                ST/C&L                USNVHTF
# Equipment Use           ST-NASF                ST/C&L                USORRSF
# Fireworks           FS-FIRESTAT                   NPS                USNVHTF
# Lightning               ST-NASF                ST/C&L                USORRSF
# Miscellaneous           ST-NASF                ST/C&L                USORRSF
# Missing/Undefined       ST-NASF                ST/C&L                USNVCCD
# Powerline               ST-NASF                ST/C&L                USNVHTF
# Railroad                ST-NASF                ST/C&L                USNVHTF
# Smoking                 ST-NASF                ST/C&L                USNVHTF
# Structure              ST-CACDF                ST/C&L                USCAYNP
#
#                                NWCG_REPORTING_UNIT_NAME SOURCE_REPORTING_UNIT  \
# STAT_CAUSE_DESCR
# Arson                            Yosemite National Park               USCASJR
# Campfire                         Yosemite National Park               USCASRR
# Children                         Yosemite National Park                 NVCCD
# Debris Burning                   Yosemite National Park               USCATKR
# Equipment Use                    Yosemite National Park               USCASJR
# Fireworks          Whiskeytown National Recreation Area                 CAWNP
# Lightning                        Yosemite National Park               USCACLR
# Miscellaneous                    Yosemite National Park               USCATNR
# Missing/Undefined                Yosemite National Park               USCATNR
# Powerline                        Yosemite National Park                 CAYNP
# Railroad                        Tuolumne-Calaveras Unit                 NVCCD
# Smoking                          Yosemite National Park                 NVCCD
# Structure                        Yosemite National Park                 CAYNP
#
#                   SOURCE_REPORTING_UNIT_NAME  ...  CONT_DATE  CONT_DOY  \
# STAT_CAUSE_DESCR                              ...
# Arson                      Yuma Field Office  ...  2457387.5     366.0
# Campfire                   Yuma Field Office  ...  2457384.5     365.0
# Children                   Yuma Field Office  ...  2457362.5     366.0
# Debris Burning             Yuma Field Office  ...  2457379.5     366.0
# Equipment Use         Yosemite National Park  ...  2457373.5     365.0
# Fireworks                  Yuma Field Office  ...  2457305.5     350.0
# Lightning                  Yuma Field Office  ...  2457356.5     365.0
# Miscellaneous              Yuma Field Office  ...  2457386.5     366.0
# Missing/Undefined     Yosemite National Park  ...  2457385.5     365.0
# Powerline             Yosemite National Park  ...  2457299.5     365.0
# Railroad             Tuolumne-Calaveras Unit  ...  2457178.5     362.0
# Smoking                    Yuma Field Office  ...  2457365.5     364.0
# Structure             Yosemite National Park  ...  2457249.5     339.0
#
#                    FIRE_SIZE  FIRE_SIZE_CLASS   LATITUDE   LONGITUDE  \
# STAT_CAUSE_DESCR
# Arson               160371.0                G  42.032500 -114.441000
# Campfire            280059.0                G  42.051667 -114.125800
# Children             38356.0                G  41.996111 -114.195800
# Debris Burning      162702.0                G  42.001944 -114.301900
# Equipment Use       240207.0                G  42.038090 -114.481111
# Fireworks             2400.0                F  41.860600 -114.200800
# Lightning           315578.8                G  42.003056 -114.140200
# Miscellaneous       255858.0                G  42.011900 -114.155500
# Missing/Undefined   108204.0                G  42.007800 -114.428056
# Powerline            47000.0                G  41.983992 -114.219400
# Railroad             55261.0                G  41.981931 -114.592700
# Smoking              43201.0                G  42.000000 -114.217400
# Structure            69363.0                G  41.516600 -114.599197
#
#                    OWNER_CODE OWNER_DESCR  STATE  \
# STAT_CAUSE_DESCR
# Arson                    15.0        USFS     CA
# Campfire                 15.0        USFS     CA
# Children                 15.0        USFS     CA
# Debris Burning           15.0        USFS     CA
# Equipment Use            15.0        USFS     CA
# Fireworks                14.0        USFS     CA
# Lightning                15.0        USFS     CA
# Miscellaneous            15.0        USFS     CA
# Missing/Undefined        15.0        USFS     CA
# Powerline                15.0        USFS     CA
# Railroad                 14.0        USFS     CA
# Smoking                  15.0        USFS     CA
# Structure                14.0      TRIBAL     CA
#
#                                                                Shape
# STAT_CAUSE_DESCR
# Arson              b'\x00\x01\xad\x10\x00\x00\xfc\xff\xff\xff\xff...
# Campfire           b'\x00\x01\xad\x10\x00\x00\xfc\xff\xff\xff\xff...
# Children           b'\x00\x01\xad\x10\x00\x00\xfc\xff\xff\xff\xff...
# Debris Burning     b'\x00\x01\xad\x10\x00\x00\xfc\xff\xff\xff\xff...
# Equipment Use      b'\x00\x01\xad\x10\x00\x00\xfc\xff\xff\xff\xff...
# Fireworks          b'\x00\x01\xad\x10\x00\x00\xfce\xf7\xe4a\xa5\\...
# Lightning          b'\x00\x01\xad\x10\x00\x00\xfc\xff\xff\xff\xff...
# Miscellaneous      b'\x00\x01\xad\x10\x00\x00\xfc\xff\xff\xff\xff...
# Missing/Undefined  b'\x00\x01\xad\x10\x00\x00\xfc\xff\xff\xff\xff...
# Powerline          b'\x00\x01\xad\x10\x00\x00\xfc\xff\xff\xff\xff...
# Railroad           b'\x00\x01\xad\x10\x00\x00\xfc\xff\xff\xff\xff...
# Smoking            b'\x00\x01\xad\x10\x00\x00\xfc\xff\xff\xff\xff...
# Structure          b'\x00\x01\xad\x10\x00\x00\xfc\x90~\xfb:\x1c^\...
#
# [13 rows x 24 columns]

# %%
groups = ca.groupby('STAT_CAUSE_DESCR')
for key, group in groups:
    print(key)
    print(group.head())
# Out:
# Arson
#       OBJECTID  FOD_ID      FPA_ID SOURCE_SYSTEM_TYPE SOURCE_SYSTEM  \
# 96          97      98  FS-1419090                FED   FS-FIRESTAT
# 407        408     415  FS-1419763                FED   FS-FIRESTAT
# 558        559     566  FS-1420114                FED   FS-FIRESTAT
# 1344      1345    1359  FS-1421854                FED   FS-FIRESTAT
# 1458      1459    1473  FS-1422081                FED   FS-FIRESTAT
#
#      NWCG_REPORTING_AGENCY NWCG_REPORTING_UNIT_ID  \
# 96                      FS                USNVHTF
# 407                     FS                USCAANF
# 558                     FS                USCAPNF
# 1344                    FS                USCACNF
# 1458                    FS                USCACNF
#
#               NWCG_REPORTING_UNIT_NAME SOURCE_REPORTING_UNIT  \
# 96    Humboldt-Toiyabe National Forest                  0417
# 407            Angeles National Forest                  0501
# 558             Plumas National Forest                  0511
# 1344         Cleveland National Forest                  0502
# 1458         Cleveland National Forest                  0502
#
#             SOURCE_REPORTING_UNIT_NAME  ... FIRE_SIZE_CLASS   LATITUDE  \
# 96    Humboldt-Toiyabe National Forest  ...               A  38.453611
# 407            Angeles National Forest  ...               A  34.186389
# 558             Plumas National Forest  ...               A  39.579722
# 1344         Cleveland National Forest  ...               C  33.345000
# 1458         Cleveland National Forest  ...               A  33.432778
#
#        LONGITUDE OWNER_CODE            OWNER_DESCR STATE COUNTY FIPS_CODE  \
# 96   -119.458611        5.0                   USFS    CA     51       051
# 407  -117.871389        5.0                   USFS    CA   None      None
# 558  -121.125278        5.0                   USFS    CA      7       007
# 1344 -116.992778       14.0  MISSING/NOT SPECIFIED    CA   None      None
# 1458 -116.860278       14.0  MISSING/NOT SPECIFIED    CA   None      None
#
#      FIPS_NAME                                              Shape
# 96        Mono  b'\x00\x01\xad\x10\x00\x00\x10\xc2i\xe2Y\xdd]\...
# 407       None  b'\x00\x01\xad\x10\x00\x00t)\xe8\xd5\xc4w]\xc0...
# 558      Butte  b'\x00\x01\xad\x10\x00\x00\xfc\x00\x18\x8d\x04...
# 1344      None  b'\x00\x01\xad\x10\x00\x00\xe8R\xd0\xab\x89?]\...
# 1458      None  b'\x00\x01\xad\x10\x00\x00\xd4\xa4\x88\xca\x0e...
#
# [5 rows x 39 columns]
# Campfire
#      OBJECTID  FOD_ID      FPA_ID SOURCE_SYSTEM_TYPE SOURCE_SYSTEM  \
# 13         14      14  FS-1418872                FED   FS-FIRESTAT
# 155       156     159  FS-1419245                FED   FS-FIRESTAT
# 156       157     160  FS-1419246                FED   FS-FIRESTAT
# 179       180     183  FS-1419303                FED   FS-FIRESTAT
# 180       181     184  FS-1419304                FED   FS-FIRESTAT
#
#     NWCG_REPORTING_AGENCY NWCG_REPORTING_UNIT_ID    NWCG_REPORTING_UNIT_NAME  \
# 13                     FS                USCAENF    Eldorado National Forest
# 155                    FS                USCALPF  Los Padres National Forest
# 156                    FS                USCALPF  Los Padres National Forest
# 179                    FS                USCALPF  Los Padres National Forest
# 180                    FS                USCALPF  Los Padres National Forest
#
#     SOURCE_REPORTING_UNIT  SOURCE_REPORTING_UNIT_NAME  ... FIRE_SIZE_CLASS  \
# 13                   0503    Eldorado National Forest  ...               B
# 155                  0507  Los Padres National Forest  ...               A
# 156                  0507  Los Padres National Forest  ...               A
# 179                  0507  Los Padres National Forest  ...               A
# 180                  0507  Los Padres National Forest  ...               A
#
#       LATITUDE   LONGITUDE OWNER_CODE            OWNER_DESCR STATE COUNTY  \
# 13   38.433333 -120.510000       14.0  MISSING/NOT SPECIFIED    CA      5
# 155  35.883611 -121.456944       13.0       STATE OR PRIVATE    CA   None
# 156  36.218056 -121.499167        5.0                   USFS    CA   None
# 179  34.855000 -119.073889        5.0                   USFS    CA   None
# 180  34.496389 -119.851111        5.0                   USFS    CA   None
#
#     FIPS_CODE FIPS_NAME                                              Shape
# 13        005    Amador  b'\x00\x01\xad\x10\x00\x00p=\n\xd7\xa3 ^\xc0\x...
# 155      None      None  b'\x00\x01\xad\x10\x00\x00\xe4x\xe4\x93>]^\xc0...
# 156      None      None  b'\x00\x01\xad\x10\x00\x00\xcc\xb9\xc2X\xf2_^\...
# 179      None      None  b'\x00\x01\xad\x10\x00\x00\x9c\x85w\x98\xba\xc...
# 180      None      None  b'\x00\x01\xad\x10\x00\x00\x94\xad\xbb\x9ax\xf...
#
# [5 rows x 39 columns]
# Children
#       OBJECTID  FOD_ID      FPA_ID SOURCE_SYSTEM_TYPE SOURCE_SYSTEM  \
# 88          89      90  FS-1419073                FED   FS-FIRESTAT
# 596        597     604  FS-1420237                FED   FS-FIRESTAT
# 2015      2016    2031  FS-1423257                FED   FS-FIRESTAT
# 2103      2104    2119  FS-1423435                FED   FS-FIRESTAT
# 2614      2615    2631  FS-1424587                FED   FS-FIRESTAT
#
#      NWCG_REPORTING_AGENCY NWCG_REPORTING_UNIT_ID   NWCG_REPORTING_UNIT_NAME  \
# 88                      FS                USCAANF    Angeles National Forest
# 596                     FS                USCAANF    Angeles National Forest
# 2015                    FS                USCAANF    Angeles National Forest
# 2103                    FS                USCACNF  Cleveland National Forest
# 2614                    FS                USCAMNF  Mendocino National Forest
#
#      SOURCE_REPORTING_UNIT SOURCE_REPORTING_UNIT_NAME  ... FIRE_SIZE_CLASS  \
# 88                    0501    Angeles National Forest  ...               B
# 596                   0501    Angeles National Forest  ...               A
# 2015                  0501    Angeles National Forest  ...               B
# 2103                  0502  Cleveland National Forest  ...               A
# 2614                  0508  Mendocino National Forest  ...               A
#
#        LATITUDE   LONGITUDE OWNER_CODE            OWNER_DESCR STATE COUNTY  \
# 88    34.153889 -117.841111       14.0  MISSING/NOT SPECIFIED    CA   None
# 596   34.228889 -117.768333        5.0                   USFS    CA   None
# 2015  34.165556 -117.904722       14.0  MISSING/NOT SPECIFIED    CA   None
# 2103  33.370556 -116.749722       14.0  MISSING/NOT SPECIFIED    CA   None
# 2614  39.127222 -122.851111       14.0  MISSING/NOT SPECIFIED    CA   None
#
#      FIPS_CODE FIPS_NAME                                              Shape
# 88        None      None  b'\x00\x01\xad\x10\x00\x00$p\xb1\xc3\xd4u]\xc0...
# 596       None      None  b'\x00\x01\xad\x10\x00\x00\xb41\x8f_,q]\xc0\xe...
# 2015      None      None  b'\x00\x01\xad\x10\x00\x00P\xb7\x06\xf8\xe6y]\...
# 2103      None      None  b'\x00\x01\xad\x10\x00\x00\x00\xff\xe7r\xfb/]\...
# 2614      None      None  b'\x00\x01\xad\x10\x00\x00\x94\xad\xbb\x9ax\xb...
#
# [5 rows x 39 columns]
# Debris Burning
#     OBJECTID  FOD_ID      FPA_ID SOURCE_SYSTEM_TYPE SOURCE_SYSTEM  \
# 2          3       3  FS-1418835                FED   FS-FIRESTAT
# 7          8       8  FS-1418854                FED   FS-FIRESTAT
# 8          9       9  FS-1418856                FED   FS-FIRESTAT
# 18        19      19  FS-1418884                FED   FS-FIRESTAT
# 76        77      78  FS-1419054                FED   FS-FIRESTAT
#
#    NWCG_REPORTING_AGENCY NWCG_REPORTING_UNIT_ID  \
# 2                     FS                USCAENF
# 7                     FS                USCASHF
# 8                     FS                USCASHF
# 18                    FS                USCAENF
# 76                    FS                USCASRF
#
#           NWCG_REPORTING_UNIT_NAME SOURCE_REPORTING_UNIT  \
# 2         Eldorado National Forest                  0503
# 7   Shasta-Trinity National Forest                  0514
# 8   Shasta-Trinity National Forest                  0514
# 18        Eldorado National Forest                  0503
# 76      Six Rivers National Forest                  0510
#
#         SOURCE_REPORTING_UNIT_NAME  ... FIRE_SIZE_CLASS   LATITUDE  \
# 2         Eldorado National Forest  ...               A  38.984167
# 7   Shasta-Trinity National Forest  ...               B  40.968056
# 8   Shasta-Trinity National Forest  ...               B  41.233611
# 18        Eldorado National Forest  ...               A  38.945000
# 76      Six Rivers National Forest  ...               A  41.037222
#
#      LONGITUDE OWNER_CODE       OWNER_DESCR STATE COUNTY FIPS_CODE  FIPS_NAME  \
# 2  -120.735556       13.0  STATE OR PRIVATE    CA     17       017  El Dorado
# 7  -122.433889       13.0  STATE OR PRIVATE    CA   None      None       None
# 8  -122.283333       13.0  STATE OR PRIVATE    CA   None      None       None
# 18 -120.411667       13.0  STATE OR PRIVATE    CA     17       017  El Dorado
# 76 -123.533056        5.0              USFS    CA   None      None       None
#
#                                                 Shape
# 2   b'\x00\x01\xad\x10\x00\x00\xd0\xa5\xa0W\x13/^\...
# 7   b'\x00\x01\xad\x10\x00\x00t)\xe8\xd5\xc4\x9b^\...
# 8   b'\x00\x01\xad\x10\x00\x00\xdc\x8d\x1e""\x92^\...
# 18  b'\x00\x01\xad\x10\x00\x004 )\xbfX\x1a^\xc00\\...
# 76  b'\x00\x01\xad\x10\x00\x00\xa8I\x11\x95\x1d\xe...
#
# [5 rows x 39 columns]
# Equipment Use
#      OBJECTID  FOD_ID      FPA_ID SOURCE_SYSTEM_TYPE SOURCE_SYSTEM  \
# 16         17      17  FS-1418878                FED   FS-FIRESTAT
# 17         18      18  FS-1418881                FED   FS-FIRESTAT
# 109       110     111  FS-1419130                FED   FS-FIRESTAT
# 110       111     112  FS-1419134                FED   FS-FIRESTAT
# 157       158     161  FS-1419247                FED   FS-FIRESTAT
#
#     NWCG_REPORTING_AGENCY NWCG_REPORTING_UNIT_ID    NWCG_REPORTING_UNIT_NAME  \
# 16                     FS                USCAENF    Eldorado National Forest
# 17                     FS                USCAENF    Eldorado National Forest
# 109                    FS                USCACNF   Cleveland National Forest
# 110                    FS                USCASNF      Sierra National Forest
# 157                    FS                USCALPF  Los Padres National Forest
#
#     SOURCE_REPORTING_UNIT  SOURCE_REPORTING_UNIT_NAME  ... FIRE_SIZE_CLASS  \
# 16                   0503    Eldorado National Forest  ...               G
# 17                   0503    Eldorado National Forest  ...               G
# 109                  0502   Cleveland National Forest  ...               C
# 110                  0515      Sierra National Forest  ...               A
# 157                  0507  Los Padres National Forest  ...               A
#
#       LATITUDE   LONGITUDE OWNER_CODE       OWNER_DESCR STATE COUNTY  \
# 16   38.523333 -120.211667        5.0              USFS    CA      5
# 17   38.780000 -120.260000        5.0              USFS    CA     17
# 109  33.718889 -117.433611       13.0  STATE OR PRIVATE    CA   None
# 110  37.044167 -119.343889       13.0  STATE OR PRIVATE    CA   None
# 157  36.448333 -121.582778        5.0              USFS    CA   None
#
#     FIPS_CODE  FIPS_NAME                                              Shape
# 16        005     Amador  b'\x00\x01\xad\x10\x00\x00dS\\\xf2\x8b\r^\xc0\...
# 17        017  El Dorado  b'\x00\x01\xad\x10\x00\x00p=\n\xd7\xa3\x10^\xc...
# 109      None       None  b'\x00\x01\xad\x10\x00\x00t(\xd0H\xc0[]\xc0\x0...
# 110      None       None  b'\x00\x01\xad\x10\x00\x00|\x00\x8cF\x02\xd6]\...
# 157      None       None  b'\x00\x01\xad\x10\x00\x00\xdc{,;Le^\xc0H\x07\...
#
# [5 rows x 39 columns]
# Fireworks
#         OBJECTID  FOD_ID    FPA_ID SOURCE_SYSTEM_TYPE SOURCE_SYSTEM  \
# 190462    190463  192871  W-456426                FED      DOI-WFMI
# 190493    190494  192902  W-456458                FED      DOI-WFMI
# 190503    190504  192912  W-456450                FED      DOI-WFMI
# 190521    190522  192931  W-456476                FED      DOI-WFMI
# 190536    190537  192946  W-456483                FED      DOI-WFMI
#
#        NWCG_REPORTING_AGENCY NWCG_REPORTING_UNIT_ID  \
# 190462                   BIA                USCACCA
# 190493                   BIA                USCACCA
# 190503                   BIA                USCACCA
# 190521                   BIA                USCACCA
# 190536                   BIA                USCACCA
#
#          NWCG_REPORTING_UNIT_NAME SOURCE_REPORTING_UNIT  \
# 190462  Central California Agency                 CACCA
# 190493  Central California Agency                 CACCA
# 190503  Central California Agency                 CACCA
# 190521  Central California Agency                 CACCA
# 190536  Central California Agency                 CACCA
#
#        SOURCE_REPORTING_UNIT_NAME  ... FIRE_SIZE_CLASS LATITUDE LONGITUDE  \
# 190462  Central California Agency  ...               A  38.9499 -123.6845
# 190493  Central California Agency  ...               A  39.2882 -123.1861
# 190503  Central California Agency  ...               A  36.9749 -119.3243
# 190521  Central California Agency  ...               A  38.9866 -123.0561
# 190536  Central California Agency  ...               C  39.1482 -122.8861
#
#        OWNER_CODE OWNER_DESCR STATE COUNTY FIPS_CODE FIPS_NAME  \
# 190462        2.0         BIA    CA   None      None      None
# 190493        2.0         BIA    CA   None      None      None
# 190503        2.0         BIA    CA   None      None      None
# 190521        2.0         BIA    CA   None      None      None
# 190536        2.0         BIA    CA   None      None      None
#
#                                                     Shape
# 190462  b'\x00\x01\xad\x10\x00\x00(\x87\x16\xd9\xce\xe...
# 190493  b'\x00\x01\xad\x10\x00\x00Dr\xf9\x0f\xe9\xcb^\...
# 190503  b'\x00\x01\xad\x10\x00\x00\xf0\x85\xc9T\xc1\xd...
# 190521  b'\x00\x01\xad\x10\x00\x00\x8cSt$\x97\xc3^\xc0...
# 190536  b'\x00\x01\xad\x10\x00\x00\x10?\xc6\xdc\xb5\xb...
#
# [5 rows x 39 columns]
# Lightning
#    OBJECTID  FOD_ID      FPA_ID SOURCE_SYSTEM_TYPE SOURCE_SYSTEM  \
# 1         2       2  FS-1418827                FED   FS-FIRESTAT
# 3         4       4  FS-1418845                FED   FS-FIRESTAT
# 4         5       5  FS-1418847                FED   FS-FIRESTAT
# 5         6       6  FS-1418849                FED   FS-FIRESTAT
# 6         7       7  FS-1418851                FED   FS-FIRESTAT
#
#   NWCG_REPORTING_AGENCY NWCG_REPORTING_UNIT_ID  NWCG_REPORTING_UNIT_NAME  \
# 1                    FS                USCAENF  Eldorado National Forest
# 3                    FS                USCAENF  Eldorado National Forest
# 4                    FS                USCAENF  Eldorado National Forest
# 5                    FS                USCAENF  Eldorado National Forest
# 6                    FS                USCAENF  Eldorado National Forest
#
#   SOURCE_REPORTING_UNIT SOURCE_REPORTING_UNIT_NAME  ... FIRE_SIZE_CLASS  \
# 1                  0503   Eldorado National Forest  ...               A
# 3                  0503   Eldorado National Forest  ...               A
# 4                  0503   Eldorado National Forest  ...               A
# 5                  0503   Eldorado National Forest  ...               A
# 6                  0503   Eldorado National Forest  ...               A
#
#     LATITUDE   LONGITUDE OWNER_CODE OWNER_DESCR STATE COUNTY FIPS_CODE  \
# 1  38.933056 -120.404444        5.0        USFS    CA     61       061
# 3  38.559167 -119.913333        5.0        USFS    CA      3       003
# 4  38.559167 -119.933056        5.0        USFS    CA      3       003
# 5  38.635278 -120.103611        5.0        USFS    CA      5       005
# 6  38.688333 -120.153333        5.0        USFS    CA     17       017
#
#    FIPS_NAME                                              Shape
# 1     Placer  b'\x00\x01\xad\x10\x00\x00T\xb6\xeej\xe2\x19^\...
# 3     Alpine  b'\x00\x01\xad\x10\x00\x00\x94\xac\xa3\rt\xfa]...
# 4     Alpine  b'\x00\x01\xad\x10\x00\x00@\xe3\xaa.\xb7\xfb]\...
# 5     Amador  b'\x00\x01\xad\x10\x00\x00\xf0<~\x90\xa1\x06^\...
# 6  El Dorado  b'\x00\x01\xad\x10\x00\x00$o\x996\xd0\t^\xc0h\...
#
# [5 rows x 39 columns]
# Miscellaneous
#      OBJECTID  FOD_ID      FPA_ID SOURCE_SYSTEM_TYPE SOURCE_SYSTEM  \
# 0           1       1  FS-1418826                FED   FS-FIRESTAT
# 12         13      13  FS-1418865                FED   FS-FIRESTAT
# 87         88      89  FS-1419071                FED   FS-FIRESTAT
# 105       106     107  FS-1419113                FED   FS-FIRESTAT
# 146       147     150  FS-1419212                FED   FS-FIRESTAT
#
#     NWCG_REPORTING_AGENCY NWCG_REPORTING_UNIT_ID   NWCG_REPORTING_UNIT_NAME  \
# 0                      FS                USCAPNF     Plumas National Forest
# 12                     FS                USCAENF   Eldorado National Forest
# 87                     FS                USCAANF    Angeles National Forest
# 105                    FS                USCACNF  Cleveland National Forest
# 146                    FS                USCASQF    Sequoia National Forest
#
#     SOURCE_REPORTING_UNIT SOURCE_REPORTING_UNIT_NAME  ... FIRE_SIZE_CLASS  \
# 0                    0511     Plumas National Forest  ...               A
# 12                   0503   Eldorado National Forest  ...               A
# 87                   0501    Angeles National Forest  ...               A
# 105                  0502  Cleveland National Forest  ...               A
# 146                  0513    Sequoia National Forest  ...               A
#
#       LATITUDE   LONGITUDE OWNER_CODE       OWNER_DESCR STATE COUNTY  \
# 0    40.036944 -121.005833        5.0              USFS    CA     63
# 12   38.786667 -120.193333        5.0              USFS    CA     17
# 87   34.174444 -117.765000        5.0              USFS    CA   None
# 105  33.666667 -117.376389       13.0  STATE OR PRIVATE    CA   None
# 146  35.768889 -118.435278       13.0  STATE OR PRIVATE    CA   None
#
#     FIPS_CODE  FIPS_NAME                                              Shape
# 0         063     Plumas  b'\x00\x01\xad\x10\x00\x00\xe8d\xc2\x92_@^\xc0...
# 12        017  El Dorado  b'\x00\x01\xad\x10\x00\x00\xe8d\xc2\x92_\x0c^\...
# 87       None       None  b'\x00\x01\xad\x10\x00\x00(\\\x8f\xc2\xf5p]\xc...
# 105      None       None  b'\x00\x01\xad\x10\x00\x00,Hm\xc1\x16X]\xc0\xe...
# 146      None       None  b'\x00\x01\xad\x10\x00\x00\xa0qU\x97\xdb\x9b]\...
#
# [5 rows x 39 columns]
# Missing/Undefined
#         OBJECTID  FOD_ID   FPA_ID SOURCE_SYSTEM_TYPE SOURCE_SYSTEM  \
# 213601    213602  216629  W-37038                FED      DOI-WFMI
# 213679    213680  216712  W-33263                FED      DOI-WFMI
# 213689    213690  216722  W-33275                FED      DOI-WFMI
# 214008    214009  217056  W-21856                FED      DOI-WFMI
# 214009    214010  217057  W-21857                FED      DOI-WFMI
#
#        NWCG_REPORTING_AGENCY NWCG_REPORTING_UNIT_ID  \
# 213601                   BLM                USCACND
# 213679                   BLM                USCACND
# 213689                   BLM                USCACND
# 214008                   BLM                USCACND
# 214009                   BLM                USCACND
#
#            NWCG_REPORTING_UNIT_NAME SOURCE_REPORTING_UNIT  \
# 213601  Central California District                 CABBD
# 213679  Central California District                 CABBD
# 213689  Central California District                 CABBD
# 214008  Central California District                 CABBD
# 214009  Central California District                 CABBD
#
#        SOURCE_REPORTING_UNIT_NAME  ... FIRE_SIZE_CLASS LATITUDE LONGITUDE  \
# 213601       Bakersfield District  ...               A  36.5166 -118.8009
# 213679       Bakersfield District  ...               B  35.2000 -118.4176
# 213689       Bakersfield District  ...               B  35.2166 -119.6010
# 214008       Bakersfield District  ...               A  35.6000 -118.4843
# 214009       Bakersfield District  ...               A  35.6000 -118.5009
#
#        OWNER_CODE OWNER_DESCR STATE COUNTY FIPS_CODE FIPS_NAME  \
# 213601        1.0         BLM    CA   None      None      None
# 213679        1.0         BLM    CA   None      None      None
# 213689        1.0         BLM    CA   None      None      None
# 214008        1.0         BLM    CA   None      None      None
# 214009        1.0         BLM    CA   None      None      None
#
#                                                     Shape
# 213601  b'\x00\x01\xad\x10\x00\x00p\xd7\x12\xf2A\xb3]\...
# 213679  b'\x00\x01\xad\x10\x00\x00\xd0\xb3Y\xf5\xb9\x9...
# 213689  b'\x00\x01\xad\x10\x00\x00T9\xb4\xc8v\xe6]\xc0...
# 214008  b'\x00\x01\xad\x10\x00\x00\xf8\\m\xc5\xfe\x9e]...
# 214009  b'\x00\x01\xad\x10\x00\x00<\xa4\xdf\xbe\x0e\xa...
#
# [5 rows x 39 columns]
# Powerline
#         OBJECTID  FOD_ID    FPA_ID SOURCE_SYSTEM_TYPE SOURCE_SYSTEM  \
# 190571    190572  192981  W-456539                FED      DOI-WFMI
# 190684    190685  193095  W-460965                FED      DOI-WFMI
# 190688    190689  193099  W-460972                FED      DOI-WFMI
# 190750    190751  193161  W-461075                FED      DOI-WFMI
# 190755    190756  193166  W-461084                FED      DOI-WFMI
#
#        NWCG_REPORTING_AGENCY NWCG_REPORTING_UNIT_ID  \
# 190571                   BIA                USCACCA
# 190684                   BIA                USCAHIA
# 190688                   BIA                USCAHIA
# 190750                   BIA                USCAHIA
# 190755                   BIA                USCAHIA
#
#          NWCG_REPORTING_UNIT_NAME SOURCE_REPORTING_UNIT  \
# 190571  Central California Agency                 CACCA
# 190684         Hoopa Valley Tribe                 CAHIA
# 190688         Hoopa Valley Tribe                 CAHIA
# 190750         Hoopa Valley Tribe                 CAHIA
# 190755         Hoopa Valley Tribe                 CAHIA
#
#        SOURCE_REPORTING_UNIT_NAME  ... FIRE_SIZE_CLASS LATITUDE LONGITUDE  \
# 190571  Central California Agency  ...               A  38.9432 -123.6528
# 190684         Hoopa Valley Tribe  ...               A  41.0665 -123.7678
# 190688         Hoopa Valley Tribe  ...               B  41.0499 -123.6512
# 190750         Hoopa Valley Tribe  ...               A  41.0832 -123.6845
# 190755         Hoopa Valley Tribe  ...               A  41.0332 -123.7678
#
#        OWNER_CODE OWNER_DESCR STATE COUNTY FIPS_CODE FIPS_NAME  \
# 190571        2.0         BIA    CA   None      None      None
# 190684        2.0         BIA    CA   None      None      None
# 190688        2.0         BIA    CA   None      None      None
# 190750        2.0         BIA    CA   None      None      None
# 190755        2.0         BIA    CA   None      None      None
#
#                                                     Shape
# 190571  b'\x00\x01\xad\x10\x00\x00\x08\xb5\xa6y\xc7\xe...
# 190684  b'\x00\x01\xad\x10\x00\x00\x98w\x9c\xa2#\xf1^\...
# 190688  b'\x00\x01\xad\x10\x00\x00\xec\xc9\xc3B\xad\xe...
# 190750  b'\x00\x01\xad\x10\x00\x00(\x87\x16\xd9\xce\xe...
# 190755  b'\x00\x01\xad\x10\x00\x00\x98w\x9c\xa2#\xf1^\...
#
# [5 rows x 39 columns]
# Railroad
#        OBJECTID  FOD_ID      FPA_ID SOURCE_SYSTEM_TYPE SOURCE_SYSTEM  \
# 5076       5077    5100  FS-1428760                FED   FS-FIRESTAT
# 6238       6239    6268  FS-1430653                FED   FS-FIRESTAT
# 6368       6369    6398  FS-1430848                FED   FS-FIRESTAT
# 8862       8863    8905  FS-1435553                FED   FS-FIRESTAT
# 14230     14231   14294  FS-1443056                FED   FS-FIRESTAT
#
#       NWCG_REPORTING_AGENCY NWCG_REPORTING_UNIT_ID  \
# 5076                     FS                USCASHF
# 6238                     FS                USCASHF
# 6368                     FS                USCASHF
# 8862                     FS                USCAKNF
# 14230                    FS                USCABDF
#
#              NWCG_REPORTING_UNIT_NAME SOURCE_REPORTING_UNIT  \
# 5076   Shasta-Trinity National Forest                  0514
# 6238   Shasta-Trinity National Forest                  0514
# 6368   Shasta-Trinity National Forest                  0514
# 8862          Klamath National Forest                  0505
# 14230  San Bernardino National Forest                  0512
#
#            SOURCE_REPORTING_UNIT_NAME  ... FIRE_SIZE_CLASS   LATITUDE  \
# 5076   Shasta-Trinity National Forest  ...               A  40.813056
# 6238   Shasta-Trinity National Forest  ...               A  40.883889
# 6368   Shasta-Trinity National Forest  ...               A  40.617500
# 8862          Klamath National Forest  ...               A  41.643611
# 14230  San Bernardino National Forest  ...               A  33.920556
#
#         LONGITUDE OWNER_CODE            OWNER_DESCR STATE COUNTY FIPS_CODE  \
# 5076  -122.324722        5.0                   USFS    CA   None      None
# 6238  -122.383611        5.0                   USFS    CA   None      None
# 6368  -123.417500        5.0                   USFS    CA   None      None
# 8862  -122.008889        5.0                   USFS    CA     93       093
# 14230 -116.750278       14.0  MISSING/NOT SPECIFIED    CA     65       065
#
#        FIPS_NAME                                              Shape
# 5076        None  b'\x00\x01\xad\x10\x00\x00\xcc\xcb\xb4?\xc8\x9...
# 6238        None  b'\x00\x01\xad\x10\x00\x00@\xf5\x9c\x15\x8d\x9...
# 6368        None  b'\x00\x01\xad\x10\x00\x00\x1c\x85\xebQ\xb8\xd...
# 8862    Siskiyou  b'\x00\x01\xad\x10\x00\x00@\xf6\xb4\xa2\x91\x8...
# 14230  Riverside  b'\x00\x01\xad\x10\x00\x00\xfc\x00\x18\x8d\x04...
# [5 rows x 39 columns]
# Smoking
#       OBJECTID  FOD_ID      FPA_ID SOURCE_SYSTEM_TYPE SOURCE_SYSTEM  \
# 181        182     185  FS-1419306                FED   FS-FIRESTAT
# 182        183     186  FS-1419307                FED   FS-FIRESTAT
# 231        232     236  FS-1419393                FED   FS-FIRESTAT
# 396        397     404  FS-1419729                FED   FS-FIRESTAT
# 1894      1895    1910  FS-1422971                FED   FS-FIRESTAT
#
#      NWCG_REPORTING_AGENCY NWCG_REPORTING_UNIT_ID    NWCG_REPORTING_UNIT_NAME  \
# 181                     FS                USCALPF  Los Padres National Forest
# 182                     FS                USCALPF  Los Padres National Forest
# 231                     FS                USCASQF     Sequoia National Forest
# 396                     FS                USCAANF     Angeles National Forest
# 1894                    FS                USCAENF    Eldorado National Forest
#
#      SOURCE_REPORTING_UNIT  SOURCE_REPORTING_UNIT_NAME  ... FIRE_SIZE_CLASS  \
# 181                   0507  Los Padres National Forest  ...               B
# 182                   0507  Los Padres National Forest  ...               A
# 231                   0513     Sequoia National Forest  ...               A
# 396                   0501     Angeles National Forest  ...               A
# 1894                  0503    Eldorado National Forest  ...               A
#
#        LATITUDE   LONGITUDE OWNER_CODE            OWNER_DESCR STATE COUNTY  \
# 181   36.242500 -121.551111        5.0                   USFS    CA   None
# 182   36.242500 -121.548056        5.0                   USFS    CA   None
# 231   35.464444 -118.756389        5.0                   USFS    CA   None
# 396   34.151667 -117.743611       14.0  MISSING/NOT SPECIFIED    CA   None
# 1894  38.901389 -120.370000        5.0                   USFS    CA   None
#
#      FIPS_CODE FIPS_NAME                                              Shape
# 181       None      None  b'\x00\x01\xad\x10\x00\x00`z\x88gEc^\xc0\xe0\x...
# 182       None      None  b'\x00\x01\xad\x10\x00\x00\xd0\xa5\xa0W\x13c^\...
# 231       None      None  b'\x00\x01\xad\x10\x00\x00\xe4f\xf2\xach\xb0]\...
# 396       None      None  b'\x00\x01\xad\x10\x00\x00\x18\x99\rS\x97o]\xc...
# 1894      None      None  b'\x00\x01\xad\x10\x00\x00D\xe1z\x14\xae\x17^\...
#
# [5 rows x 39 columns]
# Structure
#         OBJECTID  FOD_ID    FPA_ID SOURCE_SYSTEM_TYPE SOURCE_SYSTEM  \
# 190490    190491  192899  W-456469                FED      DOI-WFMI
# 190612    190613  193022  W-456577                FED      DOI-WFMI
# 191391    191392  193810  W-462123                FED      DOI-WFMI
# 191421    191422  193840  W-462168                FED      DOI-WFMI
# 191632    191633  194052  W-462447                FED      DOI-WFMI
#
#        NWCG_REPORTING_AGENCY NWCG_REPORTING_UNIT_ID  \
# 190490                   BIA                USCACCA
# 190612                   BIA                USCACCA
# 191391                   BIA                USCAHIA
# 191421                   BIA                USCAHIA
# 191632                   BIA                USCAHIA
#
#          NWCG_REPORTING_UNIT_NAME SOURCE_REPORTING_UNIT  \
# 190490  Central California Agency                 CACCA
# 190612  Central California Agency                 CACCA
# 191391         Hoopa Valley Tribe                 CAHIA
# 191421         Hoopa Valley Tribe                 CAHIA
# 191632         Hoopa Valley Tribe                 CAHIA
#
#        SOURCE_REPORTING_UNIT_NAME  ... FIRE_SIZE_CLASS LATITUDE LONGITUDE  \
# 190490  Central California Agency  ...               B  39.0085 -122.6733
# 190612  Central California Agency  ...               A  39.6782 -123.4978
# 191391         Hoopa Valley Tribe  ...               A  41.0665 -123.6678
# 191421         Hoopa Valley Tribe  ...               A  41.0832 -123.6845
# 191632         Hoopa Valley Tribe  ...               A  41.0832 -123.6845
#
#        OWNER_CODE OWNER_DESCR STATE COUNTY FIPS_CODE FIPS_NAME  \
# 190490        2.0         BIA    CA   None      None      None
# 190612        2.0         BIA    CA   None      None      None
# 191391        8.0     PRIVATE    CA   None      None      None
# 191421        8.0     PRIVATE    CA   None      None      None
# 191632        2.0         BIA    CA   None      None      None
#
#                                                     Shape
# 190490  b'\x00\x01\xad\x10\x00\x00d\x19\xe2X\x17\xab^\...
# 190612  b'\x00\x01\xad\x10\x00\x00\xb8\xfc\x87\xf4\xdb...
# 191391  b'\x00\x01\xad\x10\x00\x000\x116<\xbd\xea^\xc0...
# 191421  b'\x00\x01\xad\x10\x00\x00(\x87\x16\xd9\xce\xe...
# 191632  b'\x00\x01\xad\x10\x00\x00(\x87\x16\xd9\xce\xe...
#
# [5 rows x 39 columns]

# %%
groups = ca.groupby('STAT_CAUSE_DESCR')
for key, group in groups:
    print(key)
    print(group.max())
# Out:
# Arson
# OBJECTID                                                                1880458
# FOD_ID                                                                300348354
# FPA_ID                                                                  W-99825
# SOURCE_SYSTEM_TYPE                                                       NONFED
# SOURCE_SYSTEM                                                           ST-NASF
# NWCG_REPORTING_AGENCY                                                    ST/C&L
# NWCG_REPORTING_UNIT_ID                                                  USNVHTF
# NWCG_REPORTING_UNIT_NAME                                 Yosemite National Park
# SOURCE_REPORTING_UNIT                                                   USCASJR
# SOURCE_REPORTING_UNIT_NAME                                    Yuma Field Office
# FIRE_YEAR                                                                  2015
# DISCOVERY_DATE                                                      2.45739e+06
# DISCOVERY_DOY                                                               366
# STAT_CAUSE_CODE                                                               7
# STAT_CAUSE_DESCR                                                          Arson
# CONT_DATE                                                           2.45739e+06
# CONT_DOY                                                                    366
# FIRE_SIZE                                                                160371
# FIRE_SIZE_CLASS                                                               G
# LATITUDE                                                                42.0325
# LONGITUDE                                                              -114.441
# OWNER_CODE                                                                   15
# OWNER_DESCR                                                                USFS
# STATE                                                                        CA
# Shape                         b'\x00\x01\xad\x10\x00\x00\xfc\xff\xff\xff\xff...
# dtype: object
# Campfire
# OBJECTID                                                                1804572
# FOD_ID                                                                300218047
# FPA_ID                                                                   W-9999
# SOURCE_SYSTEM_TYPE                                                       NONFED
# SOURCE_SYSTEM                                                           ST-NASF
# NWCG_REPORTING_AGENCY                                                    ST/C&L
# NWCG_REPORTING_UNIT_ID                                                  USORRSF
# NWCG_REPORTING_UNIT_NAME                                 Yosemite National Park
# SOURCE_REPORTING_UNIT                                                   USCASRR
# SOURCE_REPORTING_UNIT_NAME                                    Yuma Field Office
# FIRE_YEAR                                                                  2015
# DISCOVERY_DATE                                                      2.45738e+06
# DISCOVERY_DOY                                                               365
# STAT_CAUSE_CODE                                                               4
# STAT_CAUSE_DESCR                                                       Campfire
# CONT_DATE                                                           2.45738e+06
# CONT_DOY                                                                    365
# FIRE_SIZE                                                                280059
# FIRE_SIZE_CLASS                                                               G
# LATITUDE                                                                42.0517
# LONGITUDE                                                              -114.126
# OWNER_CODE                                                                   15
# OWNER_DESCR                                                                USFS
# STATE                                                                        CA
# Shape                         b'\x00\x01\xad\x10\x00\x00\xfc\xff\xff\xff\xff...
# dtype: object
# Children
# OBJECTID                                                                1880454
# FOD_ID                                                                300348297
# FPA_ID                                                                   W-9912
# SOURCE_SYSTEM_TYPE                                                       NONFED
# SOURCE_SYSTEM                                                           ST-NASF
# NWCG_REPORTING_AGENCY                                                    ST/C&L
# NWCG_REPORTING_UNIT_ID                                                  USNVHTF
# NWCG_REPORTING_UNIT_NAME                                 Yosemite National Park
# SOURCE_REPORTING_UNIT                                                     NVCCD
# SOURCE_REPORTING_UNIT_NAME                                    Yuma Field Office
# COMPLEX_NAME                                                                NaN
# FIRE_YEAR                                                                  2015
# DISCOVERY_DATE                                                      2.45738e+06
# DISCOVERY_DOY                                                               366
# STAT_CAUSE_CODE                                                               8
# STAT_CAUSE_DESCR                                                       Children
# CONT_DATE                                                           2.45736e+06
# CONT_DOY                                                                    366
# FIRE_SIZE                                                                 38356
# FIRE_SIZE_CLASS                                                               G
# LATITUDE                                                                41.9961
# LONGITUDE                                                              -114.196
# OWNER_CODE                                                                   15
# OWNER_DESCR                                                                USFS
# STATE                                                                        CA
# Shape                         b'\x00\x01\xad\x10\x00\x00\xfc\xff\xff\xff\xff...
# dtype: object
# Debris Burning
# OBJECTID                                                                1880453
# FOD_ID                                                                300348293
# FPA_ID                                                                  W-99978
# SOURCE_SYSTEM_TYPE                                                       NONFED
# SOURCE_SYSTEM                                                           ST-NASF
# NWCG_REPORTING_AGENCY                                                    ST/C&L
# NWCG_REPORTING_UNIT_ID                                                  USNVHTF
# NWCG_REPORTING_UNIT_NAME                                 Yosemite National Park
# SOURCE_REPORTING_UNIT                                                   USCATKR
# SOURCE_REPORTING_UNIT_NAME                                    Yuma Field Office
# FIRE_YEAR                                                                  2015
# DISCOVERY_DATE                                                      2.45739e+06
# DISCOVERY_DOY                                                               366
# STAT_CAUSE_CODE                                                               5
# STAT_CAUSE_DESCR                                                 Debris Burning
# CONT_DATE                                                           2.45738e+06
# CONT_DOY                                                                    366
# FIRE_SIZE                                                                162702
# FIRE_SIZE_CLASS                                                               G
# LATITUDE                                                                42.0019
# LONGITUDE                                                              -114.302
# OWNER_CODE                                                                   15
# OWNER_DESCR                                                                USFS
# STATE                                                                        CA
# Shape                         b'\x00\x01\xad\x10\x00\x00\xfc\xff\xff\xff\xff...
# dtype: object
# Equipment Use
# OBJECTID                                                                1880452
# FOD_ID                                                                300348291
# FPA_ID                                                                  W-99821
# SOURCE_SYSTEM_TYPE                                                       NONFED
# SOURCE_SYSTEM                                                           ST-NASF
# NWCG_REPORTING_AGENCY                                                    ST/C&L
# NWCG_REPORTING_UNIT_ID                                                  USORRSF
# NWCG_REPORTING_UNIT_NAME                                 Yosemite National Park
# SOURCE_REPORTING_UNIT                                                   USCASJR
# SOURCE_REPORTING_UNIT_NAME                               Yosemite National Park
# FIRE_YEAR                                                                  2015
# DISCOVERY_DATE                                                      2.45737e+06
# DISCOVERY_DOY                                                               366
# STAT_CAUSE_CODE                                                               2
# STAT_CAUSE_DESCR                                                  Equipment Use
# CONT_DATE                                                           2.45737e+06
# CONT_DOY                                                                    365
# FIRE_SIZE                                                                240207
# FIRE_SIZE_CLASS                                                               G
# LATITUDE                                                                42.0381
# LONGITUDE                                                              -114.481
# OWNER_CODE                                                                   15
# OWNER_DESCR                                                                USFS
# STATE                                                                        CA
# Shape                         b'\x00\x01\xad\x10\x00\x00\xfc\xff\xff\xff\xff...
# dtype: object
# Fireworks
# OBJECTID                                                                1797737
# FOD_ID                                                                300209770
# FPA_ID                                                                   W-9917
# SOURCE_SYSTEM_TYPE                                                          FED
# SOURCE_SYSTEM                                                       FS-FIRESTAT
# NWCG_REPORTING_AGENCY                                                       NPS
# NWCG_REPORTING_UNIT_ID                                                  USNVHTF
# NWCG_REPORTING_UNIT_NAME                   Whiskeytown National Recreation Area
# SOURCE_REPORTING_UNIT                                                     CAWNP
# SOURCE_REPORTING_UNIT_NAME                                    Yuma Field Office
# FIRE_YEAR                                                                  2015
# DISCOVERY_DATE                                                       2.4573e+06
# DISCOVERY_DOY                                                               365
# DISCOVERY_TIME                                                             2357
# STAT_CAUSE_CODE                                                              10
# STAT_CAUSE_DESCR                                                      Fireworks
# CONT_DATE                                                           2.45731e+06
# CONT_DOY                                                                    350
# CONT_TIME                                                                  2359
# FIRE_SIZE                                                                  2400
# FIRE_SIZE_CLASS                                                               F
# LATITUDE                                                                41.8606
# LONGITUDE                                                              -114.201
# OWNER_CODE                                                                   14
# OWNER_DESCR                                                                USFS
# STATE                                                                        CA
# Shape                         b'\x00\x01\xad\x10\x00\x00\xfce\xf7\xe4a\xa5\\...
# dtype: object
# Lightning
# OBJECTID                                                                1880459
# FOD_ID                                                                300348361
# FPA_ID                                                                   W-9959
# SOURCE_SYSTEM_TYPE                                                       NONFED
# SOURCE_SYSTEM                                                           ST-NASF
# NWCG_REPORTING_AGENCY                                                    ST/C&L
# NWCG_REPORTING_UNIT_ID                                                  USORRSF
# NWCG_REPORTING_UNIT_NAME                                 Yosemite National Park
# SOURCE_REPORTING_UNIT                                                   USCACLR
# SOURCE_REPORTING_UNIT_NAME                                    Yuma Field Office
# FIRE_YEAR                                                                  2015
# DISCOVERY_DATE                                                      2.45735e+06
# DISCOVERY_DOY                                                               362
# STAT_CAUSE_CODE                                                               1
# STAT_CAUSE_DESCR                                                      Lightning
# CONT_DATE                                                           2.45736e+06
# CONT_DOY                                                                    365
# FIRE_SIZE                                                                315579
# FIRE_SIZE_CLASS                                                               G
# LATITUDE                                                                42.0031
# LONGITUDE                                                               -114.14
# OWNER_CODE                                                                   15
# OWNER_DESCR                                                                USFS
# STATE                                                                        CA
# Shape                         b'\x00\x01\xad\x10\x00\x00\xfc\xff\xff\xff\xff...
# dtype: object
# Miscellaneous
# OBJECTID                                                                1880465
# FOD_ID                                                                300348399
# FPA_ID                                                                   W-9966
# SOURCE_SYSTEM_TYPE                                                       NONFED
# SOURCE_SYSTEM                                                           ST-NASF
# NWCG_REPORTING_AGENCY                                                    ST/C&L
# NWCG_REPORTING_UNIT_ID                                                  USORRSF
# NWCG_REPORTING_UNIT_NAME                                 Yosemite National Park
# SOURCE_REPORTING_UNIT                                                   USCATNR
# SOURCE_REPORTING_UNIT_NAME                                    Yuma Field Office
# FIRE_YEAR                                                                  2015
# DISCOVERY_DATE                                                      2.45739e+06
# DISCOVERY_DOY                                                               366
# STAT_CAUSE_CODE                                                               9
# STAT_CAUSE_DESCR                                                  Miscellaneous
# CONT_DATE                                                           2.45739e+06
# CONT_DOY                                                                    366
# FIRE_SIZE                                                                255858
# FIRE_SIZE_CLASS                                                               G
# LATITUDE                                                                42.0119
# LONGITUDE                                                              -114.156
# OWNER_CODE                                                                   15
# OWNER_DESCR                                                                USFS
# STATE                                                                        CA
# Shape                         b'\x00\x01\xad\x10\x00\x00\xfc\xff\xff\xff\xff...
# dtype: object
# Missing/Undefined
# OBJECTID                                                                1880464
# FOD_ID                                                                300348377
# FPA_ID                                                                  W-91741
# SOURCE_SYSTEM_TYPE                                                       NONFED
# SOURCE_SYSTEM                                                           ST-NASF
# NWCG_REPORTING_AGENCY                                                    ST/C&L
# NWCG_REPORTING_UNIT_ID                                                  USNVCCD
# NWCG_REPORTING_UNIT_NAME                                 Yosemite National Park
# SOURCE_REPORTING_UNIT                                                   USCATNR
# SOURCE_REPORTING_UNIT_NAME                               Yosemite National Park
# FIRE_YEAR                                                                  2015
# DISCOVERY_DATE                                                      2.45739e+06
# DISCOVERY_DOY                                                               366
# STAT_CAUSE_CODE                                                              13
# STAT_CAUSE_DESCR                                              Missing/Undefined
# CONT_DATE                                                           2.45739e+06
# CONT_DOY                                                                    365
# FIRE_SIZE                                                                108204
# FIRE_SIZE_CLASS                                                               G
# LATITUDE                                                                42.0078
# LONGITUDE                                                              -114.428
# OWNER_CODE                                                                   15
# OWNER_DESCR                                                                USFS
# STATE                                                                        CA
# Shape                         b'\x00\x01\xad\x10\x00\x00\xfc\xff\xff\xff\xff...
# dtype: object
# Powerline
# OBJECTID                                                                1880225
# FOD_ID                                                                300346883
# FPA_ID                                                                   W-9848
# SOURCE_SYSTEM_TYPE                                                       NONFED
# SOURCE_SYSTEM                                                           ST-NASF
# NWCG_REPORTING_AGENCY                                                    ST/C&L
# NWCG_REPORTING_UNIT_ID                                                  USNVHTF
# NWCG_REPORTING_UNIT_NAME                                 Yosemite National Park
# SOURCE_REPORTING_UNIT                                                     CAYNP
# SOURCE_REPORTING_UNIT_NAME                               Yosemite National Park
# FIRE_YEAR                                                                  2015
# DISCOVERY_DATE                                                       2.4573e+06
# DISCOVERY_DOY                                                               365
# DISCOVERY_TIME                                                             2359
# STAT_CAUSE_CODE                                                              11
# STAT_CAUSE_DESCR                                                      Powerline
# CONT_DATE                                                            2.4573e+06
# CONT_DOY                                                                    365
# FIRE_SIZE                                                                 47000
# FIRE_SIZE_CLASS                                                               G
# LATITUDE                                                                 41.984
# LONGITUDE                                                              -114.219
# OWNER_CODE                                                                   15
# OWNER_DESCR                                                                USFS
# STATE                                                                        CA
# Shape                         b'\x00\x01\xad\x10\x00\x00\xfc\xff\xff\xff\xff...
# dtype: object
# Railroad
# OBJECTID                                                                1880393
# FOD_ID                                                                300348033
# FPA_ID                                                                   W-9925
# SOURCE_SYSTEM_TYPE                                                       NONFED
# SOURCE_SYSTEM                                                           ST-NASF
# NWCG_REPORTING_AGENCY                                                    ST/C&L
# NWCG_REPORTING_UNIT_ID                                                  USNVHTF
# NWCG_REPORTING_UNIT_NAME                                Tuolumne-Calaveras Unit
# SOURCE_REPORTING_UNIT                                                     NVCCD
# SOURCE_REPORTING_UNIT_NAME                              Tuolumne-Calaveras Unit
# FIRE_YEAR                                                                  2015
# DISCOVERY_DATE                                                      2.45718e+06
# DISCOVERY_DOY                                                               362
# STAT_CAUSE_CODE                                                               6
# STAT_CAUSE_DESCR                                                       Railroad
# CONT_DATE                                                           2.45718e+06
# CONT_DOY                                                                    362
# FIRE_SIZE                                                                 55261
# FIRE_SIZE_CLASS                                                               G
# LATITUDE                                                                41.9819
# LONGITUDE                                                              -114.593
# OWNER_CODE                                                                   14
# OWNER_DESCR                                                                USFS
# STATE                                                                        CA
# Shape                         b'\x00\x01\xad\x10\x00\x00\xfc\xff\xff\xff\xff...
# dtype: object
# Smoking
# OBJECTID                                                                1880402
# FOD_ID                                                                300348051
# FPA_ID                                                                   W-9922
# SOURCE_SYSTEM_TYPE                                                       NONFED
# SOURCE_SYSTEM                                                           ST-NASF
# NWCG_REPORTING_AGENCY                                                    ST/C&L
# NWCG_REPORTING_UNIT_ID                                                  USNVHTF
# NWCG_REPORTING_UNIT_NAME                                 Yosemite National Park
# SOURCE_REPORTING_UNIT                                                     NVCCD
# SOURCE_REPORTING_UNIT_NAME                                    Yuma Field Office
# COMPLEX_NAME                                                                NaN
# FIRE_YEAR                                                                  2015
# DISCOVERY_DATE                                                      2.45737e+06
# DISCOVERY_DOY                                                               365
# STAT_CAUSE_CODE                                                               3
# STAT_CAUSE_DESCR                                                        Smoking
# CONT_DATE                                                           2.45737e+06
# CONT_DOY                                                                    364
# FIRE_SIZE                                                                 43201
# FIRE_SIZE_CLASS                                                               G
# LATITUDE                                                                     42
# LONGITUDE                                                              -114.217
# OWNER_CODE                                                                   15
# OWNER_DESCR                                                                USFS
# STATE                                                                        CA
# Shape                         b'\x00\x01\xad\x10\x00\x00\xfc\xff\xff\xff\xff...
# dtype: object
# Structure
# OBJECTID                                                                1797668
# FOD_ID                                                                300209700
# FPA_ID                                                                  W-99976
# SOURCE_SYSTEM_TYPE                                                       NONFED
# SOURCE_SYSTEM                                                          ST-CACDF
# NWCG_REPORTING_AGENCY                                                    ST/C&L
# NWCG_REPORTING_UNIT_ID                                                  USCAYNP
# NWCG_REPORTING_UNIT_NAME                                 Yosemite National Park
# SOURCE_REPORTING_UNIT                                                     CAYNP
# SOURCE_REPORTING_UNIT_NAME                               Yosemite National Park
# FIRE_NAME                                                                 WOODS
# COMPLEX_NAME                                                                NaN
# FIRE_YEAR                                                                  2015
# DISCOVERY_DATE                                                      2.45723e+06
# DISCOVERY_DOY                                                               339
# DISCOVERY_TIME                                                             2341
# STAT_CAUSE_CODE                                                              12
# STAT_CAUSE_DESCR                                                      Structure
# CONT_DATE                                                           2.45725e+06
# CONT_DOY                                                                    339
# FIRE_SIZE                                                                 69363
# FIRE_SIZE_CLASS                                                               G
# LATITUDE                                                                41.5166
# LONGITUDE                                                              -114.599
# OWNER_CODE                                                                   14
# OWNER_DESCR                                                              TRIBAL
# STATE                                                                        CA
# Shape                         b'\x00\x01\xad\x10\x00\x00\xfc\x90~\xfb:\x1c^\...
# dtype: object

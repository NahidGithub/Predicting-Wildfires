# %% [markdown]
# # Creating the BSEV Model Input from Emissions/Weather Data.

# %%
import pandas as pd
import numpy as np, time
from geopy.distance import great_circle
import math
import seaborn as sns
from scipy import spatial
import matplotlib.pyplot as plt
import datetime

from sqlalchemy import create_engine

import config
import config1

# %%
# Expanding number of columns:
pd.set_option('display.max_columns', 40)

# %% [markdown]
# ### Load Data

# %%
config.db_name
# Out:
# 'db27bvsdruzh45'

# %%
# create sqlalchemy engine to access database:
engine = create_engine("mysql+mysqlconnector://{user}:{password}@{host}/{dbname}"
                       .format(user=config.db_user,
                               password=config.db_pass,
                               dbname=config.db_main,
                               host=config.db_host))

# %%
#Skip this block if reading from local disk

#Create Query Statments
queryWeather = """
SELECT *
FROM Weather;
"""
queryEmissions = """
SELECT *
FROM Emissions_Data
LIMIT 50000;
"""

# %%
# Load NASA data as primary data set for Model Table - CSV or from DB. 
NASA_M6 = pd.read_csv('/Users/AlfHaugen/Python/Wildfire_Data/FireExports/NASA-to-ClustserRef/NASA_M6_FullData_ClusterRef_May30.csv')
# Out:
# /Users/AlfHaugen/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Load Emissions data as primary data set for Model Table. 
emdata = pd.read_csv('../data/emissions_03_15_v5.24.csv')

# %%
print(emdata.shape)
emdata.head()
# Out:
# (5936438, 21)
#    Unnamed: 0  id  year  doy  longitude  latitude  covertype  fuelcode  \
# 0           0   0  2008  359   -81.0384   25.1958          3      1600
# 1           1   1  2008  359   -81.0404   25.1984          3      1600
# 2           2   2  2008  359   -81.0380   25.1981          3      1600
# 3           3   4  2008  359   -81.0594   25.2035          3      1600
# 4           4   5  2008  359   -81.0570   25.2032          3      1600
#
#    area_burned  prefire_fuel  consumed_fuel         ECO2         ECO  \
# 0          0.0   6220.097576     1999.75772  3347.594423  153.981344
# 1      62500.0   6220.097576     2041.37434  3417.260644  157.185824
# 2          0.0   6220.097576     1999.75772  3347.594423  153.981344
# 3          0.0   6220.097576     1999.75772  3347.594423  153.981344
# 4      62500.0   6220.097576     2041.37434  3417.260644  157.185824
#
#        ECH4     EPM2.5  cwd_frac  duff_frac  fuel_moisture_class  \
# 0  4.499455  23.797117  0.023231   0.082115                    3
# 1  4.593092  24.292355  0.022757   0.080441                    3
# 2  4.499455  23.797117  0.023231   0.082115                    3
# 3  4.499455  23.797117  0.023231   0.082115                    3
# 4  4.593092  24.292355  0.022757   0.080441                    3
#
#    burnday_source  BSEV cluster_reference
# 0              81     1            2008_0
# 1              81     2            2008_0
# 2              81     1            2008_0
# 3              81     1            2008_0
# 4              81     2            2008_0

# %%
#researching a single cluster reference to see how the data looks across cluster:
emdata.loc[emdata['cluster_reference'] == '2003_1980']
# Out:
#          Unnamed: 0       id  year  doy  longitude  latitude  covertype  \
# 5907041     5907041  7205653  2003   81   -93.3088   39.3217          1
# 5907042     5907042  7205654  2003   83   -93.3058   39.3217          3
#
#          fuelcode  area_burned  prefire_fuel  consumed_fuel         ECO2  \
# 5907041         1      62500.0    238.967352     222.239637   372.695872
# 5907042      2700          0.0   2639.337818    1979.738069  3076.512960
#
#                 ECO       ECH4     EPM2.5  cwd_frac  duff_frac  \
# 5907041   15.556775   0.595602   2.266844  0.000000   0.000000
# 5907042  263.305163  14.808441  45.138028  0.162671   0.157472
#
#          fuel_moisture_class  burnday_source  BSEV cluster_reference
# 5907041                    2              12     2         2003_1980
# 5907042                    2              12     1         2003_1980

# %% [markdown]
# ### Create new Feature for model input - Season using DOY:

# %%
# Function to create a feature by determining the Season by DOY = 0 is Spring, 1 is Summer, 2 is Fall and 3 is Winter:
# spring = range(80, 172)
# summer = range(172, 264)
# fall = range(264, 355)  
# winter is else, i guess you need an Else!

def get_season(doy):

    if ((doy >= 80) and (doy <= 172)):
        s = 0  # spring
    elif ((doy > 172) and (doy < 264)):
        s = 1  # summer
    elif ((doy >= 264) and (doy <= 355)):
        s = 2  # fall
    #elif ((doy > 355) and (doy < 80)):
        #s = 3  # winter
    else:
        s = 3
     #   raise IndexError("Invalid date")
    return s

# %%
#Testing function to derive the season and tag the season code. 
print(get_season(265))
# Out:
# 2

# %%
emdata['season'] = emdata.apply(lambda x: get_season(x['doy']),axis=1)  # Creating Season per DOY and tagging it as a new column in the dataframe.

# %%
emdata.head(2)
# Out:
#    Unnamed: 0  id  year  doy  longitude  latitude  covertype  fuelcode  \
# 0           0   0  2008  359   -81.0384   25.1958          3      1600
# 1           1   1  2008  359   -81.0404   25.1984          3      1600
#
#    area_burned  prefire_fuel  consumed_fuel         ECO2         ECO  \
# 0          0.0   6220.097576     1999.75772  3347.594423  153.981344
# 1      62500.0   6220.097576     2041.37434  3417.260644  157.185824
#
#        ECH4     EPM2.5  cwd_frac  duff_frac  fuel_moisture_class  \
# 0  4.499455  23.797117  0.023231   0.082115                    3
# 1  4.593092  24.292355  0.022757   0.080441                    3
#
#    burnday_source  BSEV cluster_reference  season
# 0              81     1            2008_0       3
# 1              81     2            2008_0       3

# %% [markdown]
# # Merging Weather data into the BSEV/Emissions model input.

# %% [markdown]
# ### Loading weather from SQL.

# %%
dfWeather = pd.read_sql(queryWeather, engine)  # Open up weather data from DB.

# %%
dfWeather.info() # Check for Null Values / note - some features faired better from a data pull perspective. Will clean here.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 723890 entries, 0 to 723889
# Data columns (total 15 columns):
# Key                 723890 non-null int64
# cluster_ref         723890 non-null object
# lat                 723890 non-null float64
# lon                 723890 non-null float64
# temperature         708836 non-null float64
# humidity            704865 non-null float64
# precip_intensity    664166 non-null float64
# pressure            448590 non-null float64
# uv_index            567485 non-null float64
# visibility          578296 non-null float64
# wind_speed          704241 non-null float64
# wind_gust           651392 non-null float64
# Date                723890 non-null datetime64[ns]
# year                723890 non-null int64
# doy                 723890 non-null int64
# dtypes: datetime64[ns](1), float64(10), int64(3), object(1)
# memory usage: 82.8+ MB

# %%
dfWeather.head(1)
# Out:
#    Key cluster_ref      lat      lon  temperature  humidity  precip_intensity  \
# 0    1     unknown  24.6801 -81.3504        90.67       0.8               0.0
#
#    pressure  uv_index  visibility  wind_speed  wind_gust                Date  \
# 0    1018.5       7.0       7.781       12.71       16.1 2003-05-05 12:00:00
#
#    year  doy
# 0  2003  125

# %%
dfWeather = dfWeather.rename(columns={'cluster_ref':'cluster_reference'})

# %%
dfWeather.head(5)
# Out:
#    Key cluster_reference      lat      lon  temperature  humidity  \
# 0    1           unknown  24.6801 -81.3504        90.67      0.80
# 1    2         2003_2323  24.6801 -81.3504        88.11      0.76
# 2    3         2003_2323  24.6801 -81.3504        97.81      0.67
# 3    4           unknown  24.7146 -81.3868        94.77      0.52
# 4    5         2011_3601  24.7146 -81.3868        95.79      0.50
#
#    precip_intensity  pressure  uv_index  visibility  wind_speed  wind_gust  \
# 0               0.0    1018.5       7.0       7.781       12.71      16.10
# 1               0.0    1018.8       9.0       8.656        7.19       7.19
# 2               0.0    1019.2       9.0       8.656       11.39      12.67
# 3               0.0    1018.2       8.0       9.997        5.66      10.70
# 4               0.0    1016.1       7.0       9.997        1.50       2.90
#
#                  Date  year  doy
# 0 2003-05-05 12:00:00  2003  125
# 1 2003-05-04 12:00:00  2003  124
# 2 2003-07-23 12:00:00  2003  204
# 3 2011-09-16 12:00:00  2011  259
# 4 2011-09-15 12:00:00  2011  258

# %%
dfWeather.loc[(dfWeather['lat'] == 39.3217)]
# Out:
#            Key cluster_reference      lat      lon  temperature  humidity  \
# 579193  579194           unknown  39.3217 -93.3058          NaN       NaN
# 579194  579195         2003_1980  39.3217 -93.3058          NaN       NaN
# 579195  579196         2003_1980  39.3217 -93.3058          NaN       NaN
# 579196  579197         2003_1980  39.3217 -93.3058          NaN       NaN
# 579197  579198         2003_1980  39.3217 -93.3058          NaN       NaN
# 579198  579199         2003_1980  39.3217 -93.3058          NaN       NaN
# 579199  579200         2003_1980  39.3217 -93.3058          NaN       NaN
# 579200  579201         2003_1980  39.3217 -93.3058          NaN       NaN
# 579201  579202         2003_1980  39.3217 -93.3058          NaN       NaN
# 579202  579203         2003_1980  39.3217 -93.3058          NaN       NaN
# 579203  579204         2003_1980  39.3217 -93.3058          NaN       NaN
#
#         precip_intensity  pressure  uv_index  visibility  wind_speed  \
# 579193               NaN       NaN       NaN         NaN         NaN
# 579194               NaN       NaN       NaN         NaN         NaN
# 579195               NaN       NaN       NaN         NaN         NaN
# 579196               NaN       NaN       NaN         NaN         NaN
# 579197               NaN       NaN       NaN         NaN         NaN
# 579198               NaN       NaN       NaN         NaN         NaN
# 579199               NaN       NaN       NaN         NaN         NaN
# 579200               NaN       NaN       NaN         NaN         NaN
# 579201               NaN       NaN       NaN         NaN         NaN
# 579202               NaN       NaN       NaN         NaN         NaN
# 579203               NaN       NaN       NaN         NaN         NaN
#
#         wind_gust                Date  year  doy
# 579193        NaN 2003-03-25 12:00:00  2003   84
# 579194        NaN 2003-01-01 12:00:00  2003    1
# 579195        NaN 2003-01-07 12:00:00  2003    7
# 579196        NaN 2003-01-09 12:00:00  2003    9
# 579197        NaN 2003-01-13 12:00:00  2003   13
# 579198        NaN 2003-01-14 12:00:00  2003   14
# 579199        NaN 2003-03-17 12:00:00  2003   76
# 579200        NaN 2003-03-22 12:00:00  2003   81
# 579201        NaN 2003-03-24 12:00:00  2003   83
# 579202        NaN 2003-03-26 12:00:00  2003   85
# 579203        NaN 2003-04-11 12:00:00  2003  101

# %% [markdown]
# ### Merge Weather data into Fire Brightness model input:

# %%
# Merging data into NASA M6, changing by DF above and column name. 
emdata_weather = emdata.merge(right=dfWeather.loc[:,['cluster_reference', 'temperature', 'humidity', 
                                                                    'precip_intensity', 'pressure', 'uv_index', 'visibility', 'wind_speed','wind_gust','doy']],
                   how='left',
                   left_on=['cluster_reference', 'doy'],
                   right_on=['cluster_reference', 'doy'])

# %%
print(emdata_weather.shape)
emdata_weather[0:15]
# Out:
# (6134150, 30)
#     Unnamed: 0  id  year  doy  longitude  latitude  covertype  fuelcode  \
# 0            0   0  2008  359   -81.0384   25.1958          3      1600
# 1            1   1  2008  359   -81.0404   25.1984          3      1600
# 2            2   2  2008  359   -81.0380   25.1981          3      1600
# 3            3   4  2008  359   -81.0594   25.2035          3      1600
# 4            4   5  2008  359   -81.0570   25.2032          3      1600
# 5            5   6  2008  359   -81.0545   25.2028          3      1600
# 6            6   7  2008  359   -81.0521   25.2025          3      1600
# 7            7   8  2008  359   -81.0473   25.2018          3      1600
# 8            8   9  2008  359   -81.0449   25.2014          3      1600
# 9            9  10  2008  359   -81.0400   25.2007          3      1600
# 10          10  13  2008  359   -81.0784   25.2086          3      1600
# 11          11  14  2008  359   -81.0638   25.2065          3      1600
# 12          12  15  2008  359   -81.0590   25.2058          3      1600
# 13          13  16  2008  359   -81.0566   25.2054          3      1600
# 14          14  17  2008  359   -81.0542   25.2051          1         1
#
#     area_burned  prefire_fuel  consumed_fuel         ECO2         ECO  \
# 0           0.0   6220.097576    1999.757720  3347.594423  153.981344
# 1       62500.0   6220.097576    2041.374340  3417.260644  157.185824
# 2           0.0   6220.097576    1999.757720  3347.594423  153.981344
# 3           0.0   6220.097576    1999.757720  3347.594423  153.981344
# 4       62500.0   6220.097576    2041.374340  3417.260644  157.185824
# 5       62500.0   6220.097576    2041.374340  3417.260644  157.185824
# 6           0.0   6220.097576    1999.757720  3347.594423  153.981344
# 7           0.0   6220.097576    1999.757720  3347.594423  153.981344
# 8       62500.0   6220.097576    2041.374340  3417.260644  157.185824
# 9           0.0   6220.097576    1999.757720  3347.594423  153.981344
# 10          0.0   6220.097576    1999.757720  3347.594423  153.981344
# 11          0.0   6220.097576    1999.757720  3347.594423  153.981344
# 12          0.0   6220.097576    1999.757720  3347.594423  153.981344
# 13          0.0   6220.097576    1999.757720  3347.594423  153.981344
# 14          0.0    353.182986     328.460177   550.827717   22.992212
#
#         ECH4     EPM2.5  cwd_frac  duff_frac  fuel_moisture_class  \
# 0   4.499455  23.797117  0.023231   0.082115                    3
# 1   4.593092  24.292355  0.022757   0.080441                    3
# 2   4.499455  23.797117  0.023231   0.082115                    3
# 3   4.499455  23.797117  0.023231   0.082115                    3
# 4   4.593092  24.292355  0.022757   0.080441                    3
# 5   4.593092  24.292355  0.022757   0.080441                    3
# 6   4.499455  23.797117  0.023231   0.082115                    3
# 7   4.499455  23.797117  0.023231   0.082115                    3
# 8   4.593092  24.292355  0.022757   0.080441                    3
# 9   4.499455  23.797117  0.023231   0.082115                    3
# 10  4.499455  23.797117  0.023231   0.082115                    3
# 11  4.499455  23.797117  0.023231   0.082115                    3
# 12  4.499455  23.797117  0.023231   0.082115                    3
# 13  4.499455  23.797117  0.023231   0.082115                    3
# 14  0.880273   3.350294  0.000000   0.000000                    3
#
#     burnday_source  BSEV cluster_reference  season  temperature  humidity  \
# 0               81     1            2008_0       3        75.35      0.83
# 1               81     2            2008_0       3        75.35      0.83
# 2               81     1            2008_0       3        75.35      0.83
# 3               81     1            2008_0       3        75.35      0.83
# 4               81     2            2008_0       3        75.35      0.83
# 5               81     2            2008_0       3        75.35      0.83
# 6               81     1            2008_0       3        75.35      0.83
# 7               81     1            2008_0       3        75.35      0.83
# 8               81     2            2008_0       3        75.35      0.83
# 9               81     1            2008_0       3        75.35      0.83
# 10              81     1            2008_0       3        75.35      0.83
# 11              81     1            2008_0       3        75.35      0.83
# 12              81     1            2008_0       3        75.35      0.83
# 13              81     1            2008_0       3        75.35      0.83
# 14              81     1            2008_0       3        75.35      0.83
#
#     precip_intensity  pressure  uv_index  visibility  wind_speed  wind_gust
# 0                0.0    1025.3       NaN         NaN       17.66      22.06
# 1                0.0    1025.3       NaN         NaN       17.66      22.06
# 2                0.0    1025.3       NaN         NaN       17.66      22.06
# 3                0.0    1025.3       NaN         NaN       17.66      22.06
# 4                0.0    1025.3       NaN         NaN       17.66      22.06
# 5                0.0    1025.3       NaN         NaN       17.66      22.06
# 6                0.0    1025.3       NaN         NaN       17.66      22.06
# 7                0.0    1025.3       NaN         NaN       17.66      22.06
# 8                0.0    1025.3       NaN         NaN       17.66      22.06
# 9                0.0    1025.3       NaN         NaN       17.66      22.06
# 10               0.0    1025.3       NaN         NaN       17.66      22.06
# 11               0.0    1025.3       NaN         NaN       17.66      22.06
# 12               0.0    1025.3       NaN         NaN       17.66      22.06
# 13               0.0    1025.3       NaN         NaN       17.66      22.06
# 14               0.0    1025.3       NaN         NaN       17.66      22.06

# %%
### Dropping dupes. 
emdata_weather = emdata_weather.drop_duplicates(subset=['doy', 'year', 'longitude', 'latitude', 'cluster_reference'], keep='first')

# %%
emdata_weather.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5936438 entries, 0 to 6134149
# Data columns (total 30 columns):
# Unnamed: 0             5936438 non-null int64
# id                     5936438 non-null int64
# year                   5936438 non-null int64
# doy                    5936438 non-null int64
# longitude              5936438 non-null float64
# latitude               5936438 non-null float64
# covertype              5936438 non-null int64
# fuelcode               5936438 non-null int64
# area_burned            5936438 non-null float64
# prefire_fuel           5936438 non-null float64
# consumed_fuel          5936438 non-null float64
# ECO2                   5936438 non-null float64
# ECO                    5936438 non-null float64
# ECH4                   5936438 non-null float64
# EPM2.5                 5936438 non-null float64
# cwd_frac               5936438 non-null float64
# duff_frac              5936438 non-null float64
# fuel_moisture_class    5936438 non-null int64
# burnday_source         5936438 non-null int64
# BSEV                   5936438 non-null int64
# cluster_reference      5914732 non-null object
# season                 5936438 non-null int64
# temperature            5767399 non-null float64
# humidity               5717352 non-null float64
# precip_intensity       5548025 non-null float64
# pressure               2869965 non-null float64
# uv_index               3447444 non-null float64
# visibility             3614864 non-null float64
# wind_speed             5723870 non-null float64
# wind_gust              5496961 non-null float64
# dtypes: float64(19), int64(10), object(1)
# memory usage: 1.4+ GB

# %%
# Reorder DF. 
emdata_weather = emdata_weather[['latitude', 'longitude', 'doy', 'month', 'year','cluster_reference', 'season', 'covertype', 'fuelcode', 'prefire_fuel','fuel_moisture_class',
                                                 'temperature', 'humidity', 'precip_intensity', 'pressure', 'uv_index', 'visibility', 'wind_speed','wind_gust','brightness', 'bright_t31', 'frp']]

# %% [markdown]
# ---
# ## Work to clean up BSEV/Emissions DF for weather nulls:

# %%
print(emdata_weather.shape)
emdata_weather.head()
# Out:
# (5936438, 30)
#    Unnamed: 0  id  year  doy  longitude  latitude  covertype  fuelcode  \
# 0           0   0  2008  359   -81.0384   25.1958          3      1600
# 1           1   1  2008  359   -81.0404   25.1984          3      1600
# 2           2   2  2008  359   -81.0380   25.1981          3      1600
# 3           3   4  2008  359   -81.0594   25.2035          3      1600
# 4           4   5  2008  359   -81.0570   25.2032          3      1600
#
#    area_burned  prefire_fuel  consumed_fuel         ECO2         ECO  \
# 0          0.0   6220.097576     1999.75772  3347.594423  153.981344
# 1      62500.0   6220.097576     2041.37434  3417.260644  157.185824
# 2          0.0   6220.097576     1999.75772  3347.594423  153.981344
# 3          0.0   6220.097576     1999.75772  3347.594423  153.981344
# 4      62500.0   6220.097576     2041.37434  3417.260644  157.185824
#
#        ECH4     EPM2.5  cwd_frac  duff_frac  fuel_moisture_class  \
# 0  4.499455  23.797117  0.023231   0.082115                    3
# 1  4.593092  24.292355  0.022757   0.080441                    3
# 2  4.499455  23.797117  0.023231   0.082115                    3
# 3  4.499455  23.797117  0.023231   0.082115                    3
# 4  4.593092  24.292355  0.022757   0.080441                    3
#
#    burnday_source  BSEV cluster_reference  season  temperature  humidity  \
# 0              81     1            2008_0       3        75.35      0.83
# 1              81     2            2008_0       3        75.35      0.83
# 2              81     1            2008_0       3        75.35      0.83
# 3              81     1            2008_0       3        75.35      0.83
# 4              81     2            2008_0       3        75.35      0.83
#
#    precip_intensity  pressure  uv_index  visibility  wind_speed  wind_gust
# 0               0.0    1025.3       NaN         NaN       17.66      22.06
# 1               0.0    1025.3       NaN         NaN       17.66      22.06
# 2               0.0    1025.3       NaN         NaN       17.66      22.06
# 3               0.0    1025.3       NaN         NaN       17.66      22.06
# 4               0.0    1025.3       NaN         NaN       17.66      22.06

# %%
# Dropping two features given the number of Nulls. 
emdata_weather = emdata_weather.drop(columns=['pressure','uv_index'])

# %%
emdata_weather.head(1)
# Out:
#    Unnamed: 0  id  year  doy  longitude  latitude  covertype  fuelcode  \
# 0           0   0  2008  359   -81.0384   25.1958          3      1600
#
#    area_burned  prefire_fuel  consumed_fuel         ECO2         ECO  \
# 0          0.0   6220.097576     1999.75772  3347.594423  153.981344
#
#        ECH4     EPM2.5  cwd_frac  duff_frac  fuel_moisture_class  \
# 0  4.499455  23.797117  0.023231   0.082115                    3
#
#    burnday_source  BSEV cluster_reference  season  temperature  humidity  \
# 0              81     1            2008_0       3        75.35      0.83
#
#    precip_intensity  visibility  wind_speed  wind_gust
# 0               0.0         NaN       17.66      22.06

# %%
emdata_weather = emdata_weather.dropna(subset=['temperature'])

# %%
emdata_weather[['precip_intensity']] = emdata_weather[['precip_intensity']].fillna(value=0)

# %%
emdata_weather.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5717352 entries, 0 to 6134149
# Data columns (total 27 columns):
# Unnamed: 0             5717352 non-null int64
# id                     5717352 non-null int64
# year                   5717352 non-null int64
# doy                    5717352 non-null int64
# longitude              5717352 non-null float64
# latitude               5717352 non-null float64
# covertype              5717352 non-null int64
# fuelcode               5717352 non-null int64
# area_burned            5717352 non-null float64
# prefire_fuel           5717352 non-null float64
# consumed_fuel          5717352 non-null float64
# ECO2                   5717352 non-null float64
# ECO                    5717352 non-null float64
# ECH4                   5717352 non-null float64
# EPM2.5                 5717352 non-null float64
# cwd_frac               5717352 non-null float64
# duff_frac              5717352 non-null float64
# fuel_moisture_class    5717352 non-null int64
# burnday_source         5717352 non-null int64
# BSEV                   5717352 non-null int64
# cluster_reference      5717352 non-null object
# season                 5717352 non-null int64
# temperature            5717352 non-null float64
# humidity               5717352 non-null float64
# precip_intensity       5717352 non-null float64
# wind_speed             5690831 non-null float64
# wind_gust              5472308 non-null float64
# dtypes: float64(16), int64(10), object(1)
# memory usage: 1.2+ GB

# %%
emdata_weather = emdata_weather.dropna(subset=['humidity'])

# %%
emdata_weather = emdata_weather.drop(columns=['visibility'])

# %%
# Creating Means for features

wind_speed_mean = emdata_weather['wind_speed'].mean()
wind_gust_mean = emdata_weather['wind_gust'].mean()

print(wind_speed_mean, wind_gust_mean)
# Out:
# 7.904928151963509 14.492237774220422

# %%
weather_values = {'wind_speed': wind_speed_mean, 'wind_gust': wind_gust_mean}
emdata_weather = emdata_weather.fillna(value=weather_values)

# %%
emdata_weather = emdata_weather.drop(columns={'Unnamed: 0','area_burned', 'burnday_source'})

# %%
emdata_weather.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5717352 entries, 0 to 6134149
# Data columns (total 24 columns):
# id                     5717352 non-null int64
# year                   5717352 non-null int64
# doy                    5717352 non-null int64
# longitude              5717352 non-null float64
# latitude               5717352 non-null float64
# covertype              5717352 non-null int64
# fuelcode               5717352 non-null int64
# prefire_fuel           5717352 non-null float64
# consumed_fuel          5717352 non-null float64
# ECO2                   5717352 non-null float64
# ECO                    5717352 non-null float64
# ECH4                   5717352 non-null float64
# EPM2.5                 5717352 non-null float64
# cwd_frac               5717352 non-null float64
# duff_frac              5717352 non-null float64
# fuel_moisture_class    5717352 non-null int64
# BSEV                   5717352 non-null int64
# cluster_reference      5717352 non-null object
# season                 5717352 non-null int64
# temperature            5717352 non-null float64
# humidity               5717352 non-null float64
# precip_intensity       5717352 non-null float64
# wind_speed             5717352 non-null float64
# wind_gust              5717352 non-null float64
# dtypes: float64(15), int64(8), object(1)
# memory usage: 1.1+ GB

# %%
emdata_weather.to_csv('/Users/AlfHaugen/Python/Wildfire_Data/FireExports/BSEV_Model_June12.csv',index=False)

# %% [markdown]
# ---
# ## Adding Regions into BSEV Model:

# %%
BSEV_model = pd.read_csv('../data/BSEV_Model_June12.csv')

# %%
print(BSEV_model.shape)
BSEV_model.head(3)
# Out:
# (5717352, 24)
#    id  year  doy  longitude  latitude  covertype  fuelcode  prefire_fuel  \
# 0   0  2008  359   -81.0384   25.1958          3      1600   6220.097576
# 1   1  2008  359   -81.0404   25.1984          3      1600   6220.097576
# 2   2  2008  359   -81.0380   25.1981          3      1600   6220.097576
#
#    consumed_fuel         ECO2         ECO      ECH4     EPM2.5  cwd_frac  \
# 0     1999.75772  3347.594423  153.981344  4.499455  23.797117  0.023231
# 1     2041.37434  3417.260644  157.185824  4.593092  24.292355  0.022757
# 2     1999.75772  3347.594423  153.981344  4.499455  23.797117  0.023231
#
#    duff_frac  fuel_moisture_class  BSEV cluster_reference  season  \
# 0   0.082115                    3     1            2008_0       3
# 1   0.080441                    3     2            2008_0       3
# 2   0.082115                    3     1            2008_0       3
#
#    temperature  humidity  precip_intensity  wind_speed  wind_gust
# 0        75.35      0.83               0.0       17.66      22.06
# 1        75.35      0.83               0.0       17.66      22.06
# 2        75.35      0.83               0.0       17.66      22.06

# %%
BSEV_model['unique_id'] = BSEV_model['cluster_reference'].astype(str) + "_" + BSEV_model['latitude'].astype(str)

# %% [markdown]
# #### Merging Fire Regions to dataframe:

# %%
bsev_regions = pd.read_csv('../data/BSEV_Model_Regions_June12.csv')

# %%
print(bsev_regions.shape)
bsev_regions.head(6)
# Out:
# (5717352, 5)
#    year  longitude  latitude       unique_id  cluster_label
# 0  2008   -81.0384   25.1958  2008_0_25.1958              2
# 1  2008   -81.0404   25.1984  2008_0_25.1984              2
# 2  2008   -81.0380   25.1981  2008_0_25.1981              2
# 3  2008   -81.0594   25.2035  2008_0_25.2035              2
# 4  2008   -81.0570   25.2032  2008_0_25.2032              2
# 5  2008   -81.0545   25.2028  2008_0_25.2028              2

# %%
# Merging data into NASA M6, changing by DF above and column name. 
BSEV_model_ii = BSEV_model.merge(right=bsev_regions.loc[:,['unique_id', 'cluster_label']],
                   how='left',
                   left_on=['unique_id'],
                   right_on=['unique_id'])

# %%
print(BSEV_model_ii.shape)
BSEV_model_ii.head(3)
# Out:
# (21580892, 26)
#    id  year  doy  longitude  latitude  covertype  fuelcode  prefire_fuel  \
# 0   0  2008  359   -81.0384   25.1958          3      1600   6220.097576
# 1   1  2008  359   -81.0404   25.1984          3      1600   6220.097576
# 2   2  2008  359   -81.0380   25.1981          3      1600   6220.097576
#
#    consumed_fuel         ECO2         ECO      ECH4     EPM2.5  cwd_frac  \
# 0     1999.75772  3347.594423  153.981344  4.499455  23.797117  0.023231
# 1     2041.37434  3417.260644  157.185824  4.593092  24.292355  0.022757
# 2     1999.75772  3347.594423  153.981344  4.499455  23.797117  0.023231
#
#    duff_frac  fuel_moisture_class  BSEV cluster_reference  season  \
# 0   0.082115                    3     1            2008_0       3
# 1   0.080441                    3     2            2008_0       3
# 2   0.082115                    3     1            2008_0       3
#
#    temperature  humidity  precip_intensity  wind_speed  wind_gust  \
# 0        75.35      0.83               0.0       17.66      22.06
# 1        75.35      0.83               0.0       17.66      22.06
# 2        75.35      0.83               0.0       17.66      22.06
#
#         unique_id  cluster_label
# 0  2008_0_25.1958              2
# 1  2008_0_25.1984              2
# 2  2008_0_25.1981              2

# %%
BSEV_model_ii = BSEV_model_ii.drop_duplicates(subset=['latitude', 'longitude', 'doy', 'year','unique_id'], keep='first')

# %%
print(BSEV_model_ii.shape)
BSEV_model_ii.head(3)
# Out:
# (5717352, 26)
#    id  year  doy  longitude  latitude  covertype  fuelcode  prefire_fuel  \
# 0   0  2008  359   -81.0384   25.1958          3      1600   6220.097576
# 1   1  2008  359   -81.0404   25.1984          3      1600   6220.097576
# 2   2  2008  359   -81.0380   25.1981          3      1600   6220.097576
#
#    consumed_fuel         ECO2         ECO      ECH4     EPM2.5  cwd_frac  \
# 0     1999.75772  3347.594423  153.981344  4.499455  23.797117  0.023231
# 1     2041.37434  3417.260644  157.185824  4.593092  24.292355  0.022757
# 2     1999.75772  3347.594423  153.981344  4.499455  23.797117  0.023231
#
#    duff_frac  fuel_moisture_class  BSEV cluster_reference  season  \
# 0   0.082115                    3     1            2008_0       3
# 1   0.080441                    3     2            2008_0       3
# 2   0.082115                    3     1            2008_0       3
#
#    temperature  humidity  precip_intensity  wind_speed  wind_gust  \
# 0        75.35      0.83               0.0       17.66      22.06
# 1        75.35      0.83               0.0       17.66      22.06
# 2        75.35      0.83               0.0       17.66      22.06
#
#         unique_id  cluster_label
# 0  2008_0_25.1958              2
# 1  2008_0_25.1984              2
# 2  2008_0_25.1981              2

# %%
BSEV_model_ii = BSEV_model_ii.drop(columns = {'unique_id'})

# %%
BSEV_model_ii = BSEV_model_ii.rename(columns = {'cluster_label':'fire_bsev_region'})

# %%
BSEV_model_ii = BSEV_model_ii[['id', 'year', 'doy', 'longitude', 'latitude', 'cluster_reference', 'fire_bsev_region', 'season', 'covertype',
                               'fuelcode', 'prefire_fuel', 'consumed_fuel', 'fuel_moisture_class','temperature', 'humidity', 'precip_intensity',
                               'wind_speed', 'wind_gust', 'cwd_frac', 'duff_frac', 'BSEV','ECO2', 'ECO', 'ECH4', 'EPM2.5']]

# %%
print(BSEV_model_ii.shape)
BSEV_model_ii.head(3)
# Out:
# (5717352, 25)
#    id  year  doy  longitude  latitude cluster_reference  fire_bsev_region  \
# 0   0  2008  359   -81.0384   25.1958            2008_0                 2
# 1   1  2008  359   -81.0404   25.1984            2008_0                 2
# 2   2  2008  359   -81.0380   25.1981            2008_0                 2
#
#    season  covertype  fuelcode  prefire_fuel  consumed_fuel  \
# 0       3          3      1600   6220.097576     1999.75772
# 1       3          3      1600   6220.097576     2041.37434
# 2       3          3      1600   6220.097576     1999.75772
#
#    fuel_moisture_class  temperature  humidity  precip_intensity  wind_speed  \
# 0                    3        75.35      0.83               0.0       17.66
# 1                    3        75.35      0.83               0.0       17.66
# 2                    3        75.35      0.83               0.0       17.66
#
#    wind_gust  cwd_frac  duff_frac  BSEV         ECO2         ECO      ECH4  \
# 0      22.06  0.023231   0.082115     1  3347.594423  153.981344  4.499455
# 1      22.06  0.022757   0.080441     2  3417.260644  157.185824  4.593092
# 2      22.06  0.023231   0.082115     1  3347.594423  153.981344  4.499455
#
#       EPM2.5
# 0  23.797117
# 1  24.292355
# 2  23.797117

# %%
BSEV_model_ii.to_csv('../data/BSEV_Model_June13.csv')

# %%
BSEV_model_ii.to_sql('BSEV_Model', con = engine, if_exists = 'replace', chunksize = 100000)
